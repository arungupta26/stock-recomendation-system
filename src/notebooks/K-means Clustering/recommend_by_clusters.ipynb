# %%
# In this section we adopt K-Means Clustering to get similar stocks for recommendation

import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from sklearn.cluster import KMeans

# %%
# First load the dataset on stock basics
dataset = pd.read_csv('./data/stock_basics.csv')
stocks = dataset.iloc[:,0].values
print("Below is stock list in dataset:")
print(stocks)
print("-------------------------------------------------------------")

features = dataset.iloc[:,1:].values
features = pd.DataFrame(features)
features.columns = ["Price", "Volume", "Market Cap", "Beta", "PE Ratio", "EPS"]
cols = features.columns
features[cols] = features[cols].apply(pd.to_numeric, errors='coerce')
print("Below is the data of stock features: ")
print(features)

# Second we eliminate null values in the dataset
for i in features.columns:
    features[i] = features[i].fillna(int(features[i].mean()))
# Out:
# Below is stock list in dataset:
# ['AARTIIND.NS' 'ABBOTINDIA.NS' 'ACC.NS' 'ADANIENT.NS' 'ADANIPORTS.NS'
#  'ABFRL.NS' 'APLLTD.NS' 'ALKEM.NS' 'AMARAJABAT.NS' 'AMBUJACEM.NS'
#  'APOLLOHOSP.NS' 'APOLLOTYRE.NS' 'ASHOKLEY.NS' 'ASIANPAINT.NS' 'ASTRAL.NS'
#  'AUBANK.NS' 'AUROPHARMA.NS' 'AXISBANK.NS' 'BAJAJ-AUTO.NS' 'BAJFINANCE.NS'
#  'BAJAJFINSV.NS' 'BALKRISIND.NS' 'BANDHANBNK.NS' 'BANKBARODA.NS'
#  'BATAINDIA.NS' 'BERGEPAINT.NS' 'BEL.NS' 'BHARATFORG.NS' 'BPCL.NS'
#  'BHARTIARTL.NS' 'BHEL.NS' 'BIOCON.NS' 'BOSCHLTD.NS' 'BRITANNIA.NS'
#  'CADILAHC.NS' 'CANFINHOME.NS' 'CANBK.NS' 'CHOLAFIN.NS' 'CIPLA.NS'
#  'CUB.NS' 'COALINDIA.NS' 'COFORGE.NS' 'COLPAL.NS' 'CONCOR.NS'
#  'COROMANDEL.NS' 'CROMPTON.NS' 'CUMMINSIND.NS' 'DABUR.NS' 'DALBHARAT.NS'
#  'DEEPAKNTR.NS' 'DELTACORP.NS' 'DIVISLAB.NS' 'DIXON.NS' 'DLF.NS'
#  'LALPATHLAB.NS' 'DRREDDY.NS' 'EICHERMOT.NS' 'ESCORTS.NS' 'EXIDEIND.NS'
#  'FEDERALBNK.NS' 'GAIL.NS' 'GLENMARK.NS' 'GMRINFRA.NS' 'GODREJCP.NS'
#  'GODREJPROP.NS' 'GRANULES.NS' 'GRASIM.NS' 'GUJGASLTD.NS' 'HAVELLS.NS'
#  'HCLTECH.NS' 'HDFCAMC.NS' 'HDFCBANK.NS' 'HDFCLIFE.NS' 'HDFC.NS'
#  'HEROMOTOCO.NS' 'HINDALCO.NS' 'HAL.NS' 'HINDPETRO.NS' 'HINDUNILVR.NS'
#  'ICICIBANK.NS' 'ICICIGI.NS' 'ICICIPRULI.NS' 'IDFCFIRSTB.NS'
#  'IBULHSGFIN.NS' 'INDIAMART.NS' 'IEX.NS' 'IOC.NS' 'IRCTC.NS' 'IGL.NS'
#  'INDUSTOWER.NS' 'INDUSINDBK.NS' 'NAUKRI.NS' 'INFY.NS' 'INDIGO.NS'
#  'IPCALAB.NS' 'ITC.NS' 'JINDALSTEL.NS' 'JKCEMENT.NS' 'JSWSTEEL.NS'
#  'JUBLFOOD.NS' 'KOTAKBANK.NS' 'L&TFH.NS' 'LTI.NS' 'LTTS.NS' 'LT.NS'
#  'LICHSGFIN.NS' 'LUPIN.NS' 'M&MFIN.NS' 'MGL.NS' 'M&M.NS' 'MANAPPURAM.NS'
#  'MARICO.NS' 'MARUTI.NS' 'MFSL.NS' 'METROPOLIS.NS' 'MINDTREE.NS'
#  'MOTHERSUMI.NS' 'MPHASIS.NS' 'MRF.NS' 'MCX.NS' 'MUTHOOTFIN.NS'
#  'NATIONALUM.NS' 'NAVINFLUOR.NS' 'NESTLEIND.NS' 'NMDC.NS' 'NTPC.NS'
#  'OBEROIRLTY.NS' 'ONGC.NS' 'OFSS.NS' 'PAGEIND.NS' 'PERSISTENT.NS'
#  'PETRONET.NS' 'PFIZER.NS' 'PIIND.NS' 'PIDILITIND.NS' 'PEL.NS'
#  'POLYCAB.NS' 'PFC.NS' 'POWERGRID.NS' 'PNB.NS' 'PVR.NS' 'RBLBANK.NS'
#  'RECLTD.NS' 'RELIANCE.NS' 'SBILIFE.NS' 'SHREECEM.NS' 'SIEMENS.NS'
#  'SRF.NS' 'SBIN.NS' 'SAIL.NS' 'STAR.NS' 'SUNPHARMA.NS' 'SUNTV.NS'
#  'SYNGENE.NS' 'TATACHEM.NS' 'TCS.NS' 'TATACONSUM.NS' 'TATAMOTORS.NS'
#  'TATAPOWER.NS' 'TATASTEEL.NS' 'TECHM.NS' 'INDIACEM.NS' 'INDHOTEL.NS'
#  'RAMCOCEM.NS' 'TITAN.NS' 'TORNTPHARM.NS' 'TORNTPOWER.NS' 'TRENT.NS'
#  'TVSMOTOR.NS' 'ULTRACEMCO.NS' 'UBL.NS' 'MCDOWELL-N.NS' 'UPL.NS' 'VEDL.NS'
#  'IDEA.NS' 'VOLTAS.NS' 'WIPRO.NS' 'ZEEL.NS']
# -------------------------------------------------------------
# Below is the data of stock features:
#         Price     Volume     Market Cap  Beta  PE Ratio     EPS
# 0     1083.00     791677   390870000000  0.63     59.65   18.07
# 1    17239.00      13295   362155000000 -0.07     50.40  337.75
# 2     2261.00     443238   418874000000  0.64     20.42  109.11
# 3     1839.80    2205958  2037000000000  0.95    200.80    9.22
# 4      761.75    4693246  1523000000000  0.87     29.74   25.08
# ..        ...        ...            ...   ...       ...     ...
# 173    319.50   20437568  1219000000000  1.58      6.52   49.81
# 174     11.85  325819956   356212000000  0.64       NaN  -15.40
# 175   1260.20     806276   415244000000  0.67     70.27   17.86
# 176    631.00    7357382  3394000000000  0.67     28.11   22.10
# 177    316.45   18870693   305012000000  0.56     26.34   12.05
#
# [178 rows x 6 columns]

# %%
def gen_clusters(features, columns, clusterNum, clusterPrint): 
    print("Creating clusters:")
    print( columns, clusterNum, clusterPrint)
    kmeans = KMeans(n_clusters=clusterNum,init='k-means++',max_iter=300,n_init=10,random_state=0) 

    clusterIds = kmeans.fit_predict(features[columns])
    
    # First initialize each cluster
    clusters = []
    for i in range(0, clusterNum):
        clusters.append([])

    # Second fill cluster with stocks
    stockId = 0
    for clusterId in clusterIds:
        stock = stocks[stockId]
        clusters[clusterId].append(stock)
        stockId += 1 
        
    # Print out cluster
    if clusterPrint == 1:
        print("Here are generated clusters:\n")
        clusterId = 1
        for i in range(0, clusterNum):
            print("cluster-" + str(clusterId) + ": " + ",".join(clusters[i]))
            clusterId += 1
    return clusters

# %%
# Now we start to recommend stocks
# First input stock symbol of google (googl) and stock features you care about, the system will return a list of stocks in the same cluster
# You are free to modify to other stock symbol and concerned features to test
# 
# Available feature ID and name pair are lsited as below:
# 1: "Price", 
# 2: "Volume", 
# 3: "Market Cap", 
# 4: "Beta", 
# 5: "PE Ratio"
# 6: "EPS"

# Here users want to recommendation based on price and volume for Amazon Inc.
stock_input = "PAGEIND.NS"
fids_concerned = [1,2]

# Here cluster number is set to be 100 so that each cluster has 15 stocks on average
clusterNum = 80
clusterPrint = 1
columns = []
for fid in fids_concerned:
    columns.append(features.columns[fid-1])
clusters = gen_clusters(features, columns, clusterNum, clusterPrint)

print("Stock you have input: " + stock_input)
print("Features you are concerned about: " + ', '.join(columns))
print("---------------------------------------------------")
count = 0
isfound = 0
for cluster in clusters:
    if stock_input in cluster and len(cluster)>1:
        isfound = 1
        print("Here are a list of stocks you may be interested in:\n")
        for cluster_stock in cluster:
            if cluster_stock != stock_input:
                count += 1
                print("Stock-" + str(count) + ": " + cluster_stock)
                print("=====================================")
        break        
if not isfound:
    print("Sorry, we can not make any recommendation based on your input")
# Out:
# Creating clusters:
# ['Price', 'Volume'] 80 1
# Here are generated clusters:
#
# cluster-1: L&TFH.NS
# cluster-2: IDEA.NS
# cluster-3: BHEL.NS
# cluster-4: DEEPAKNTR.NS,GODREJCP.NS,GRASIM.NS,INDIGO.NS,MINDTREE.NS,TORNTPOWER.NS
# cluster-5: IBULHSGFIN.NS
# cluster-6: PNB.NS
# cluster-7: ASHOKLEY.NS
# cluster-8: IDFCFIRSTB.NS,NATIONALUM.NS
# cluster-9: HINDPETRO.NS,M&M.NS
# cluster-10: ADANIENT.NS,AUROPHARMA.NS,CUB.NS,HDFCLIFE.NS
# cluster-11: BEL.NS,HDFCBANK.NS,JINDALSTEL.NS
# cluster-12: GAIL.NS
# cluster-13: TATAPOWER.NS
# cluster-14: BANKBARODA.NS
# cluster-15: ITC.NS,SBIN.NS
# cluster-16: BAJAJFINSV.NS,DALBHARAT.NS,LALPATHLAB.NS,NAVINFLUOR.NS,TORNTPHARM.NS
# cluster-17: ICICIBANK.NS,ONGC.NS
# cluster-18: AXISBANK.NS
# cluster-19: SAIL.NS
# cluster-20: GLENMARK.NS,SUNTV.NS,TITAN.NS
# cluster-21: GMRINFRA.NS
# cluster-22: ABFRL.NS,JSWSTEEL.NS
# cluster-23: IEX.NS
# cluster-24: COALINDIA.NS,POWERGRID.NS
# cluster-25: HDFC.NS
# cluster-26: DIVISLAB.NS,HEROMOTOCO.NS,JUBLFOOD.NS,MFSL.NS,PIDILITIND.NS,PEL.NS
# cluster-27: INDUSINDBK.NS,INFY.NS
# cluster-28: HINDALCO.NS
# cluster-29: RBLBANK.NS
# cluster-30: ESCORTS.NS
# cluster-31: TATASTEEL.NS,WIPRO.NS
# cluster-32: RECLTD.NS
# cluster-33: ABBOTINDIA.NS,BOSCHLTD.NS,NESTLEIND.NS,PFIZER.NS,SHREECEM.NS
# cluster-34: AARTIIND.NS,BERGEPAINT.NS,MPHASIS.NS,TRENT.NS,VOLTAS.NS
# cluster-35: IRCTC.NS
# cluster-36: ZEEL.NS
# cluster-37: CHOLAFIN.NS,UPL.NS
# cluster-38: ADANIPORTS.NS
# cluster-39: MOTHERSUMI.NS
# cluster-40: BHARTIARTL.NS
# cluster-41: INDUSTOWER.NS,MANAPPURAM.NS,INDIACEM.NS
# cluster-42: AUBANK.NS,CONCOR.NS,GODREJPROP.NS,LUPIN.NS,MARICO.NS,OBEROIRLTY.NS,PVR.NS,SBILIFE.NS,SRF.NS
# cluster-43: APLLTD.NS,ASTRAL.NS,BAJAJ-AUTO.NS,COFORGE.NS,COROMANDEL.NS,DIXON.NS,DRREDDY.NS,RAMCOCEM.NS
# cluster-44: HCLTECH.NS
# cluster-45: TATAMOTORS.NS
# cluster-46: DLF.NS
# cluster-47: CANBK.NS
# cluster-48: HAVELLS.NS,IPCALAB.NS,STAR.NS
# cluster-49: DELTACORP.NS
# cluster-50: EXIDEIND.NS,LT.NS,LICHSGFIN.NS
# cluster-51: BIOCON.NS,TVSMOTOR.NS
# cluster-52: TATACHEM.NS
# cluster-53: CADILAHC.NS,GRANULES.NS,IGL.NS,MCDOWELL-N.NS
# cluster-54: BANDHANBNK.NS
# cluster-55: FEDERALBNK.NS
# cluster-56: BPCL.NS
# cluster-57: NTPC.NS
# cluster-58: CUMMINSIND.NS,EICHERMOT.NS,HAL.NS,MARUTI.NS,SYNGENE.NS
# cluster-59: PETRONET.NS
# cluster-60: BALKRISIND.NS,BRITANNIA.NS,HDFCAMC.NS,LTTS.NS,METROPOLIS.NS,PERSISTENT.NS,ULTRACEMCO.NS
# cluster-61: PFC.NS,SUNPHARMA.NS
# cluster-62: AMARAJABAT.NS,APOLLOHOSP.NS,CANFINHOME.NS,MUTHOOTFIN.NS
# cluster-63: M&MFIN.NS
# cluster-64: CROMPTON.NS,HINDUNILVR.NS
# cluster-65: KOTAKBANK.NS
# cluster-66: VEDL.NS
# cluster-67: ALKEM.NS,INDIAMART.NS,JKCEMENT.NS,OFSS.NS
# cluster-68: ACC.NS,BATAINDIA.NS,COLPAL.NS,MGL.NS,POLYCAB.NS,SIEMENS.NS
# cluster-69: IOC.NS,NMDC.NS
# cluster-70: BHARATFORG.NS,DABUR.NS,TATACONSUM.NS
# cluster-71: RELIANCE.NS
# cluster-72: AMBUJACEM.NS,TECHM.NS
# cluster-73: MRF.NS,PAGEIND.NS
# cluster-74: APOLLOTYRE.NS
# cluster-75: CIPLA.NS,TCS.NS
# cluster-76: INDHOTEL.NS
# cluster-77: NAUKRI.NS,LTI.NS,PIIND.NS,UBL.NS
# cluster-78: ASIANPAINT.NS,ICICIPRULI.NS
# cluster-79: BAJFINANCE.NS,GUJGASLTD.NS
# cluster-80: ICICIGI.NS,MCX.NS
# Stock you have input: PAGEIND.NS
# Features you are concerned about: Price, Volume
# ---------------------------------------------------
# Here are a list of stocks you may be interested in:
#
# Stock-1: MRF.NS
# =====================================

# %%
# Out:
# 20
# 40
# 60
# 80
# 100
# 120
# 140
# 160

# %%
# Out:
# ['AARTIIND.NS',
#  'ABBOTINDIA.NS',
#  'ACC.NS',
#  'ADANIENT.NS',
#  'ADANIPORTS.NS',
#  'ABFRL.NS',
#  'APLLTD.NS',
#  'ALKEM.NS',
#  'AMARAJABAT.NS',
#  'AMBUJACEM.NS',
#  'APOLLOHOSP.NS',
#  'APOLLOTYRE.NS',
#  'ASHOKLEY.NS',
#  'ASIANPAINT.NS',
#  'ASTRAL.NS',
#  'AUBANK.NS',
#  'AUROPHARMA.NS',
#  'AXISBANK.NS',
#  'BAJAJ-AUTO.NS',
#  'BAJFINANCE.NS',
#  'BAJAJFINSV.NS',
#  'BALKRISIND.NS',
#  'BANDHANBNK.NS',
#  'BANKBARODA.NS',
#  'BATAINDIA.NS',
#  'BERGEPAINT.NS',
#  'BEL.NS',
#  'BHARATFORG.NS',
#  'BPCL.NS',
#  'BHARTIARTL.NS',
#  'BHEL.NS',
#  'BIOCON.NS',
#  'BOSCHLTD.NS',
#  'BRITANNIA.NS',
#  'CADILAHC.NS',
#  'CANFINHOME.NS',
#  'CANBK.NS',
#  'CHOLAFIN.NS',
#  'CIPLA.NS',
#  'CUB.NS',
#  'COALINDIA.NS',
#  'COFORGE.NS',
#  'COLPAL.NS',
#  'CONCOR.NS',
#  'COROMANDEL.NS',
#  'CROMPTON.NS',
#  'CUMMINSIND.NS',
#  'DABUR.NS',
#  'DALBHARAT.NS',
#  'DEEPAKNTR.NS',
#  'DELTACORP.NS',
#  'DIVISLAB.NS',
#  'DIXON.NS',
#  'DLF.NS',
#  'LALPATHLAB.NS',
#  'DRREDDY.NS',
#  'EICHERMOT.NS',
#  'ESCORTS.NS',
#  'EXIDEIND.NS',
#  'FEDERALBNK.NS',
#  'GAIL.NS',
#  'GLENMARK.NS',
#  'GMRINFRA.NS',
#  'GODREJCP.NS',
#  'GODREJPROP.NS',
#  'GRANULES.NS',
#  'GRASIM.NS',
#  'GUJGASLTD.NS',
#  'HAVELLS.NS',
#  'HCLTECH.NS',
#  'HDFCAMC.NS',
#  'HDFCBANK.NS',
#  'HDFCLIFE.NS',
#  'HDFC.NS',
#  'HEROMOTOCO.NS',
#  'HINDALCO.NS',
#  'HAL.NS',
#  'HINDPETRO.NS',
#  'HINDUNILVR.NS',
#  'ICICIBANK.NS',
#  'ICICIGI.NS',
#  'ICICIPRULI.NS',
#  'IDFCFIRSTB.NS',
#  'IBULHSGFIN.NS',
#  'INDIAMART.NS',
#  'IEX.NS',
#  'IOC.NS',
#  'IRCTC.NS',
#  'IGL.NS',
#  'INDUSTOWER.NS',
#  'INDUSINDBK.NS',
#  'NAUKRI.NS',
#  'INFY.NS',
#  'INDIGO.NS',
#  'IPCALAB.NS',
#  'ITC.NS',
#  'JINDALSTEL.NS',
#  'JKCEMENT.NS',
#  'JSWSTEEL.NS',
#  'JUBLFOOD.NS',
#  'KOTAKBANK.NS',
#  'L&TFH.NS',
#  'LTI.NS',
#  'LTTS.NS',
#  'LT.NS',
#  'LICHSGFIN.NS',
#  'LUPIN.NS',
#  'M&MFIN.NS',
#  'MGL.NS',
#  'M&M.NS',
#  'MANAPPURAM.NS',
#  'MARICO.NS',
#  'MARUTI.NS',
#  'MFSL.NS',
#  'METROPOLIS.NS',
#  'MINDTREE.NS',
#  'MOTHERSUMI.NS',
#  'MPHASIS.NS',
#  'MRF.NS',
#  'MCX.NS',
#  'MUTHOOTFIN.NS',
#  'NATIONALUM.NS',
#  'NAVINFLUOR.NS',
#  'NESTLEIND.NS',
#  'NAM-INDIA.NS',
#  'NMDC.NS',
#  'NTPC.NS',
#  'OBEROIRLTY.NS',
#  'ONGC.NS',
#  'OFSS.NS',
#  'PAGEIND.NS',
#  'PERSISTENT.NS',
#  'PETRONET.NS',
#  'PFIZER.NS',
#  'PIIND.NS',
#  'PIDILITIND.NS',
#  'PEL.NS',
#  'POLYCAB.NS',
#  'PFC.NS',
#  'POWERGRID.NS',
#  'PNB.NS',
#  'PVR.NS',
#  'RBLBANK.NS',
#  'RECLTD.NS',
#  'RELIANCE.NS',
#  'SBILIFE.NS',
#  'SHREECEM.NS',
#  'SRTRANSFIN.NS',
#  'SIEMENS.NS',
#  'SRF.NS',
#  'SBIN.NS',
#  'SAIL.NS',
#  'STAR.NS',
#  'SUNPHARMA.NS',
#  'SUNTV.NS',
#  'SYNGENE.NS',
#  'TATACHEM.NS',
#  'TCS.NS',
#  'TATACONSUM.NS',
#  'TATAMOTORS.NS',
#  'TATAPOWER.NS',
#  'TATASTEEL.NS',
#  'TECHM.NS',
#  'INDIACEM.NS',
#  'INDHOTEL.NS',
#  'RAMCOCEM.NS',
#  'TITAN.NS',
#  'TORNTPHARM.NS',
#  'TORNTPOWER.NS',
#  'TRENT.NS',
#  'TVSMOTOR.NS',
#  'ULTRACEMCO.NS',
#  'UBL.NS',
#  'MCDOWELL-N.NS',
#  'UPL.NS',
#  'VEDL.NS',
#  'IDEA.NS',
#  'VOLTAS.NS',
#  'WIPRO.NS',
#  'ZEEL.NS']

# %%
html = requests.get('https://finance.yahoo.com/quote/ABBOTINDIA.NS?p=ABBOTINDIA.NS')
soup = BeautifulSoup(html.text, features="lxml")

# %%
soup
# Out:
# <!DOCTYPE html>
# <html lang="en-us"><head>
# <meta content="text/html; charset=utf-8" http-equiv="content-type"/>
# <meta charset="utf-8"/>
# <title>Yahoo</title>
# <meta content="width=device-width,initial-scale=1,minimal-ui" name="viewport"/>
# <meta content="IE=edge,chrome=1" http-equiv="X-UA-Compatible"/>
# <style>
#   html {
#       height: 100%;
#   }
#   body {
#       background: #fafafc url(https://s.yimg.com/nn/img/sad-panda-201402200631.png) 50% 50%;
#       background-size: cover;
#       height: 100%;
#       text-align: center;
#       font: 300 18px "helvetica neue", helvetica, verdana, tahoma, arial, sans-serif;
#   }
#   table {
#       height: 100%;
#       width: 100%;
#       table-layout: fixed;
#       border-collapse: collapse;
#       border-spacing: 0;
#       border: none;
#   }
#   h1 {
#       font-size: 42px;
#       font-weight: 400;
#       color: #400090;
#   }
#   p {
#       color: #1A1A1A;
#   }
#   #message-1 {
#       font-weight: bold;
#       margin: 0;
#   }
#   #message-2 {
#       display: inline-block;
#       *display: inline;
#       zoom: 1;
#       max-width: 17em;
#       _width: 17em;
#   }
#       </style>
# <script>
#     document.write('<img src="//geo.yahoo.com/b?s=1197757129&t='+new Date().getTime()+'&src=aws&err_url='+encodeURIComponent(document.URL)+'&err=%<pssc>&test='+encodeURIComponent('%<{Bucket}cqh[:200]>')+'" width="0px" height="0px"/>');var beacon = new Image();beacon.src="//bcn.fp.yahoo.com/p?s=1197757129&t="+new Date().getTime()+"&src=aws&err_url="+encodeURIComponent(document.URL)+"&err=%<pssc>&test="+encodeURIComponent('%<{Bucket}cqh[:200]>');
#   </script>
# </head>
# <body>
# <!-- status code : 404 -->
# <!-- Not Found on Server -->
# <table>
# <tbody><tr>
# <td>
# <img alt="Yahoo Logo" src="https://s.yimg.com/rz/p/yahoo_frontpage_en-US_s_f_p_205x58_frontpage.png"/>
# <h1 style="margin-top:20px;">Will be right back...</h1>
# <p id="message-1">Thank you for your patience.</p>
# <p id="message-2">Our engineers are working quickly to resolve the issue.</p>
# </td>
# </tr>
# </tbody></table>
# </body></html>

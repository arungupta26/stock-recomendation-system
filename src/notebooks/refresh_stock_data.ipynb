# %%
from sklearn import  linear_model
import matplotlib.pyplot as pl

import yfinance as yf
import pandas as pd
import numpy as np
from fbprophet import Prophet
from pathlib import Path
import pickle

#!pip install yfinance

from datetime import date

stock_coefficient_file_name= './../resources/Stock_Coefficients.csv'

# Considering data from 2000 to till date for latest trend
start = '2018-01-01'
end = date.today().strftime("%Y-%m-%d")

# %%
# function1 to get stock list from text file
def get_list(filename):
    # pandas read file into data frame
    stocks = pd.read_csv(filename, header = None)
    stocks[0] = stocks[0].str.upper()
    # convert the data frame to numpy array
    stock_array = stocks.values
    return stock_array

# %%
from pandas_datareader._utils import RemoteDataError

# Considering data from 2018 to 2019 for latest trend
# start = '2018-01-01'
# end = '2022-02-01' #date.today().strftime("%Y-%m-%d")

# function2: get historical data for a specific stock, using symbol as the parameter
def load_stock_data(symbol):
    try:

        df = yf.download(symbol , start , end )
        #web.DataReader(symbol, 'yahoo', start, end)
    except RemoteDataError:
        print("No search result : '" + symbol + "'")
        return float('NaN')
    except KeyError:
        print("Date range not supported : '" + symbol + "'")
        return float('NaN')
    close = df[['Close']]

    # Normalize close value by divided by the base value (the close price of the earliest day) and multiplied by 100
    base = close.iloc[0]['Close']
    # neglect the stocks the initial close price < 25 USD to insure the selected stock value
    if base > 10 :
        close = close.assign(Close = close['Close'] / base * 100)
    return close



from sklearn.model_selection import train_test_split

# function3: build linear regression model for a specific stock
# parameter
# show_statistics: indicate if the statistics are printed
# show_dots: indicate if dots data needed
# show_plot: indacate if the plot is shown

#The coefficient estimates for Ordinary Least Squares rely on the independence of the features.
#When features are correlated and the columns of the design matrix  have an approximately linear dependence,
#the design matrix becomes close to singular and as a result, the least-squares estimate becomes highly sensitive to random errors in the observed target,
#producing a large variance.

def build_linear_regression(symbol, show_statistics = True, show_dots = True, show_plot = True):
    close = load_stock_data(symbol)
    # if the close is not dataframe, return NaN

    if not isinstance(close, pd.DataFrame) :
        return float('NaN')

    # normalize datatime datatype to integer
    # simply converting datetime's to # of days since 2018-04-01 divided by 100
    close.index = (close.index - pd.to_datetime('2019-01-01')).days / 100
    close = close.reset_index()
    train, test= train_test_split(close)

    train_x = train.drop('Close', axis = 1)
    train_y = train[['Close']]
    test_x = test.drop('Close', axis = 1)
    test_y = test[['Close']]

    #call linear regression model
    regr = linear_model.LinearRegression()
    regr.fit(train_x,train_y)

    if show_statistics :
        # The coefficients
        print('Coefficients         ->', regr.coef_[0])
        # The mean squared error
        print("Mean squared error   -> %.2f"
              % np.mean((regr.predict(test_x) - test_y) ** 2))
        # Explained variance score: 1 is perfect prediction
        print('Variance score       -> %.2f' % regr.score(test_x, test_y))
        print('features             ->', 'Date', 'Stock Close Price')

    if show_plot :
        pl.plot(test_x, regr.predict(test_x), label = symbol)
        pl.legend()

        # Plot outputs
        pl.xlabel('Date')
        pl.ylabel('Close Price')
        pl.title('Overall Linear Regression Model')

        if show_dots :
            #pl.title(symbol + ' Linear Regression Model')
            pl.plot(test['Date'], test['Close'], linestyle='none', marker='o')

        pl.xticks(())
        pl.yticks(())
    # return the coefficient representing trend
    return regr.coef_[0][0]

# function4: for each symbol in the text file, caculate the coefficents and record in the original text file
def get_coefficient_dataset(filename, show_statistics = False, show_dots = False, show_plot = False) :
    # load stock list data from text file
    stock_array = get_list(filename)
    # extend the 2D array from N * 1 to N * 2 to make place for putting corresponding coefficient
    stock_array = np.insert(stock_array, 1, values=0, axis=1)
    stock_array = np.insert(stock_array, 1, values=0, axis=1)

    # caculate coefficient for each symbol and store in the stock_array
    for symbol in stock_array:
        print(symbol)
        coefficient  = build_linear_regression(symbol[0], show_statistics, show_dots, show_plot)
        symbol[1] = coefficient


        df = yf.download(symbol[0] , start , end )
        lastData = df[-2:]['Close']
        deltaPercentage = (lastData[1]-lastData[0]) / lastData[1] * 100
        symbol[2] = deltaPercentage


        # break

    # transfer stock_array to dataframe with two columns 'Stock' and 'Coefficient'
    coefficient_data = pd.DataFrame(stock_array)

    coefficient_data.columns = ['Stock', 'Coefficient', 'LastDayChange']


    # store the dataframe to csv file for future using
    coefficient_data.to_csv(stock_coefficient_file_name)
    return coefficient_data

# %%
# function4 using example using stock_list_test.txt
coefficient_data_test = get_coefficient_dataset('./../resources/stock_list.txt')
coefficient_data_test
# Out:
# ['AARTIIND.NS' 0 0]
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# ['ABBOTINDIA.NS' 0 0]
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# ['ACC.NS' 0 0]
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# ['ADANIENT.NS' 0 0]
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# ['ADANIPORTS.NS' 0 0]
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# ['ABFRL.NS' 0 0]
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# ['APLLTD.NS' 0 0]
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# ['ALKEM.NS' 0 0]
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# ['AMARAJABAT.NS' 0 0]
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# ['AMBUJACEM.NS' 0 0]
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# ['APOLLOHOSP.NS' 0 0]
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# ['APOLLOTYRE.NS' 0 0]
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# ['ASHOKLEY.NS' 0 0]
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# ['ASIANPAINT.NS' 0 0]
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# ['ASTRAL.NS' 0 0]
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# ['AUBANK.NS' 0 0]
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# ['AUROPHARMA.NS' 0 0]
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# ['AXISBANK.NS' 0 0]
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# ['BAJAJ-AUTO.NS' 0 0]
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# ['BAJFINANCE.NS' 0 0]
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# ['BAJAJFINSV.NS' 0 0]
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# ['BALKRISIND.NS' 0 0]
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# ['BANDHANBNK.NS' 0 0]
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# ['BANKBARODA.NS' 0 0]
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# ['BATAINDIA.NS' 0 0]
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# ['BERGEPAINT.NS' 0 0]
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# ['BEL.NS' 0 0]
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# ['BHARATFORG.NS' 0 0]
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# ['BPCL.NS' 0 0]
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# ['BHARTIARTL.NS' 0 0]
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# ['BHEL.NS' 0 0]
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# ['BIOCON.NS' 0 0]
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# ['BOSCHLTD.NS' 0 0]
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# ['BRITANNIA.NS' 0 0]
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# ['CADILAHC.NS' 0 0]
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# ['CANFINHOME.NS' 0 0]
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# ['CANBK.NS' 0 0]
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# ['CHOLAFIN.NS' 0 0]
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# ['CIPLA.NS' 0 0]
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# ['CUB.NS' 0 0]
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# ['COALINDIA.NS' 0 0]
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# ['COFORGE.NS' 0 0]
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# ['COLPAL.NS' 0 0]
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# ['CONCOR.NS' 0 0]
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# ['COROMANDEL.NS' 0 0]
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# ['CROMPTON.NS' 0 0]
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# ['CUMMINSIND.NS' 0 0]
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# ['DABUR.NS' 0 0]
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# ['DALBHARAT.NS' 0 0]
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# ['DEEPAKNTR.NS' 0 0]
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# ['DELTACORP.NS' 0 0]
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# ['DIVISLAB.NS' 0 0]
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# ['DIXON.NS' 0 0]
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# ['DLF.NS' 0 0]
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# ['LALPATHLAB.NS' 0 0]
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# ['DRREDDY.NS' 0 0]
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# ['EICHERMOT.NS' 0 0]
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# ['ESCORTS.NS' 0 0]
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# ['EXIDEIND.NS' 0 0]
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# ['FEDERALBNK.NS' 0 0]
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# ['GAIL.NS' 0 0]
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# ['GLENMARK.NS' 0 0]
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# ['GMRINFRA.NS' 0 0]
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# ['GODREJCP.NS' 0 0]
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# ['GODREJPROP.NS' 0 0]
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# ['GRANULES.NS' 0 0]
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# ['GRASIM.NS' 0 0]
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# ['GUJGASLTD.NS' 0 0]
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# ['HAVELLS.NS' 0 0]
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# ['HCLTECH.NS' 0 0]
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# ['HDFCAMC.NS' 0 0]
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# ['HDFCBANK.NS' 0 0]
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# ['HDFCLIFE.NS' 0 0]
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# ['HDFC.NS' 0 0]
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# ['HEROMOTOCO.NS' 0 0]
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# ['HINDALCO.NS' 0 0]
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# ['HAL.NS' 0 0]
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# ['HINDPETRO.NS' 0 0]
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# ['HINDUNILVR.NS' 0 0]
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# ['ICICIBANK.NS' 0 0]
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# ['ICICIGI.NS' 0 0]
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# ['ICICIPRULI.NS' 0 0]
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# ['IDFCFIRSTB.NS' 0 0]
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# ['IBULHSGFIN.NS' 0 0]
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# ['INDIAMART.NS' 0 0]
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# ['IEX.NS' 0 0]
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# ['IOC.NS' 0 0]
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# ['IRCTC.NS' 0 0]
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# ['IGL.NS' 0 0]
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# ['INDUSTOWER.NS' 0 0]
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# ['INDUSINDBK.NS' 0 0]
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# ['NAUKRI.NS' 0 0]
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# ['INFY.NS' 0 0]
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# ['INDIGO.NS' 0 0]
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# ['IPCALAB.NS' 0 0]
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# ['ITC.NS' 0 0]
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# ['JINDALSTEL.NS' 0 0]
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# ['JKCEMENT.NS' 0 0]
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# ['JSWSTEEL.NS' 0 0]
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# ['JUBLFOOD.NS' 0 0]
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# ['KOTAKBANK.NS' 0 0]
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# ['L&TFH.NS' 0 0]
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# ['LTI.NS' 0 0]
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# ['LTTS.NS' 0 0]
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# ['LT.NS' 0 0]
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# ['LICHSGFIN.NS' 0 0]
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# ['LUPIN.NS' 0 0]
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# ['M&MFIN.NS' 0 0]
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# ['MGL.NS' 0 0]
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# ['M&M.NS' 0 0]
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# ['MANAPPURAM.NS' 0 0]
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# ['MARICO.NS' 0 0]
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# ['MARUTI.NS' 0 0]
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# ['MFSL.NS' 0 0]
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# ['METROPOLIS.NS' 0 0]
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# ['MINDTREE.NS' 0 0]
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# ['MOTHERSUMI.NS' 0 0]
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# ['MPHASIS.NS' 0 0]
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# ['MRF.NS' 0 0]
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# ['MCX.NS' 0 0]
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# ['MUTHOOTFIN.NS' 0 0]
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# ['NATIONALUM.NS' 0 0]
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# ['NAVINFLUOR.NS' 0 0]
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# ['NESTLEIND.NS' 0 0]
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# ['NMDC.NS' 0 0]
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# ['NTPC.NS' 0 0]
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# ['OBEROIRLTY.NS' 0 0]
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# ['ONGC.NS' 0 0]
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# ['OFSS.NS' 0 0]
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# ['PAGEIND.NS' 0 0]
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# ['PERSISTENT.NS' 0 0]
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# ['PETRONET.NS' 0 0]
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# ['PFIZER.NS' 0 0]
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# ['PIIND.NS' 0 0]
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# ['PIDILITIND.NS' 0 0]
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# ['PEL.NS' 0 0]
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# ['POLYCAB.NS' 0 0]
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# ['PFC.NS' 0 0]
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# ['POWERGRID.NS' 0 0]
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# ['PNB.NS' 0 0]
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# ['PVR.NS' 0 0]
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# ['RBLBANK.NS' 0 0]
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# ['RECLTD.NS' 0 0]
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# ['RELIANCE.NS' 0 0]
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# ['SBILIFE.NS' 0 0]
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# ['SHREECEM.NS' 0 0]
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# ['SIEMENS.NS' 0 0]
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# ['SRF.NS' 0 0]
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# ['SBIN.NS' 0 0]
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# ['SAIL.NS' 0 0]
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# ['STAR.NS' 0 0]
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# ['SUNPHARMA.NS' 0 0]
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# ['SUNTV.NS' 0 0]
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# ['SYNGENE.NS' 0 0]
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# ['TATACHEM.NS' 0 0]
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# ['TCS.NS' 0 0]
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# ['TATACONSUM.NS' 0 0]
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# ['TATAMOTORS.NS' 0 0]
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# ['TATAPOWER.NS' 0 0]
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# ['TATASTEEL.NS' 0 0]
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# ['TECHM.NS' 0 0]
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# ['INDIACEM.NS' 0 0]
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# ['INDHOTEL.NS' 0 0]
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# ['RAMCOCEM.NS' 0 0]
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# ['TITAN.NS' 0 0]
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# ['TORNTPHARM.NS' 0 0]
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# ['TORNTPOWER.NS' 0 0]
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# ['TRENT.NS' 0 0]
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# ['TVSMOTOR.NS' 0 0]
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# ['ULTRACEMCO.NS' 0 0]
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# ['UBL.NS' 0 0]
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# ['MCDOWELL-N.NS' 0 0]
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# ['UPL.NS' 0 0]
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# ['VEDL.NS' 0 0]
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# ['IDEA.NS' 0 0]
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# ['VOLTAS.NS' 0 0]
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# ['WIPRO.NS' 0 0]
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# ['ZEEL.NS' 0 0]
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
#              Stock Coefficient LastDayChange
# 0      AARTIIND.NS   17.130787       0.87247
# 1    ABBOTINDIA.NS   18.520434      -1.38237
# 2           ACC.NS     2.61298     -0.828667
# 3      ADANIENT.NS  116.276944      0.310139
# 4    ADANIPORTS.NS    6.451586     -0.763462
# ..             ...         ...           ...
# 173        VEDL.NS    0.414024      3.100889
# 174        IDEA.NS    -3.56876      -0.44248
# 175      VOLTAS.NS    6.529941      1.166267
# 176       WIPRO.NS    12.01787     -1.136861
# 177        ZEEL.NS   -4.431387      -3.30579
#
# [178 rows x 3 columns]

# %%
from datetime import date

import datetime



# # Considering data from 2000 to 2022
# start = datetime.datetime(2018, 1, 1)
# end = date.today().strftime("%Y-%m-%d")

stocks = Path('./../resources/stock_list.txt').read_text().split("\n")
index=1
for s in stocks:
    print(s)
    df = yf.download( s, start , end)
    close = df['Close']

    close_df = close.reset_index().rename(columns={'Date':'ds', 'Close':'y'})
    close_df['y'] = np.log(close_df['y'])
    model = Prophet(daily_seasonality=True)
    model.fit(close_df)
    pkl_path = "./../resources/fbprophet/model/"+s+".model"
    with open(pkl_path, "wb") as f:
        pickle.dump(model, f)

    #     # save the dataframe
    #     forecast.to_pickle("./../../resources/fbprophet/forecast/"+s+".forecast")
    print(index,"*** Data Saved for -> ",s)
    index = index+1
# Out:
# AARTIIND.NS
# [*********************100%***********************]  1 of 1 completed
# Initial log joint probability = -2.23477
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#       99       4345.96   0.000629705       576.598           1           1      121
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      199       4374.72   0.000268121       833.207           1           1      234
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      299       4393.01    0.00138763       1133.71           1           1      354
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      399       4401.74   0.000945255       1753.78           1           1      477
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      499       4415.77   0.000318844          1804      0.9174      0.9174      592
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      599       4426.37    0.00432784       732.702           1           1      707
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      699       4428.25   0.000143421       1218.08      0.1515           1      822
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      799       4429.93    0.00604738       2177.82           1           1      934
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      899       4433.72   0.000178614       199.639           1           1     1059
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      999       4434.57   2.86471e-05        114.12           1           1     1183
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#     1099       4435.71   3.46486e-05       912.616     0.02841           1     1297
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#     1199       4436.17   0.000620186       445.706      0.4776           1     1419
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#     1299        4437.7    0.00389238       777.816           1           1     1536
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#     1399        4440.8   0.000118691       245.835           1           1     1658
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#     1499       4441.67   3.28572e-05       617.216      0.1874           1     1777
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#     1544       4441.93   5.83354e-06       245.051   6.936e-08       0.001     1874  LS failed, Hessian reset
#     1599       4442.05   0.000649869       122.095           1           1     1942
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#     1699       4442.28   3.74978e-05       141.981           1           1     2065
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#     
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#     3021       5240.31    7.1343e-07       264.117   2.976e-09       0.001     3584  LS failed, Hessian reset
#     3099       5240.37    0.00035255        352.61           1           1     3673
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#     3199       5240.55   0.000225524       416.434           1           1     3786
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#     3299       5241.23    4.2458e-05       1285.63      0.5438      0.5438     3900
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#     3399       5241.39   9.51695e-05       285.631           1           1     4025
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#     3499       5241.56   9.54001e-05       869.868           1           1     4146
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#     3571       5241.68   4.77573e-07       167.288   4.472e-09       0.001     4282  LS failed, Hessian reset
#     3599       5241.72   8.05107e-06       206.415           1           1     4310
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#     3691       5241.78   1.00953e-06       311.786   1.529e-09       0.001     4466  LS failed, Hessian reset
#     3699       5241.79   7.94086e-07       275.718      0.3148      0.3148     4476
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#     3799       5241.83   4.84345e-06       80.3177      0.4766      0.4766     4604
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#     3899       5242.15    0.00184702       1115.22           1           1     4725
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#     3999        5242.6   0.000197168       698.468      0.1584      0.1584     4840
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#     4099       5243.65   3.37039e-05       425.354      0.2023      0.2023     4965
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#     4199       5244.05   0.000129262       247.093           1           1     5081
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#     4299       5244.39   6.03713e-05       388.724           1           1     5195
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#     4399       5244.63   4.73161e-05       1040.83      0.1982      0.1982     5313
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#     4442       5244.65   1.64725e-05       32.3493           1           1     5362
# Optimization terminated normally:
#   Convergence detected: relative gradient magnitude is below tolerance
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# KeyboardInterrupt:
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# /var/folders/xm/04s2ld0n1jqbwfgytc7tjrf00000gn/T/ipykernel_3227/177248526.py in <module>
#      19     close_df['y'] = np.log(close_df['y'])
#      20     model = Prophet(daily_seasonality=True)
# ---> 21     model.fit(close_df)
#      22     pkl_path = "./../resources/fbprophet/model/"+s+".model"
#      23     with open(pkl_path, "wb") as f:
#
# ~/opt/anaconda3/lib/python3.9/site-packages/fbprophet/forecaster.py in fit(self, df, **kwargs)
#    1164             self.params = self.stan_backend.sampling(stan_init, dat, self.mcmc_samples, **kwargs)
#    1165         else:
# -> 1166             self.params = self.stan_backend.fit(stan_init, dat, **kwargs)
#    1167
#    1168         # If no changepoints were requested, replace delta with 0s
#
# ~/opt/anaconda3/lib/python3.9/site-packages/fbprophet/models.py in fit(self, stan_init, stan_data, **kwargs)
#     243         args.update(kwargs)
#     244         try:
# --> 245             self.stan_fit = self.model.optimizing(**args)
#     246         except RuntimeError:
#     247             # Fall back on Newton
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pystan/model.py in optimizing(self, data, seed, init, sample_file, algorithm, verbose, as_vector, **kwargs)
#     579         stan_args = pystan.misc._get_valid_stan_args(stan_args)
#     580
# --> 581         ret, sample = fit._call_sampler(stan_args)
#     582         pars = pystan.misc._par_vector2dict(sample['par'], m_pars, p_dims)
#     583         if not as_vector:
#
# stanfit4anon_model_dfdaf2b8ece8a02eb11f050ec701c0ec_8383813421034673541.pyx in stanfit4anon_model_dfdaf2b8ece8a02eb11f050ec701c0ec_8383813421034673541.StanFit4Model._call_sampler()
#
# stanfit4anon_model_dfdaf2b8ece8a02eb11f050ec701c0ec_8383813421034673541.pyx in stanfit4anon_model_dfdaf2b8ece8a02eb11f050ec701c0ec_8383813421034673541._call_sampler()
#
# stanfit4anon_model_dfdaf2b8ece8a02eb11f050ec701c0ec_8383813421034673541.pyx in stanfit4anon_model_dfdaf2b8ece8a02eb11f050ec701c0ec_8383813421034673541._pystanholder_from_stanholder()
#
# SystemError: <class 'stanfit4anon_model_dfdaf2b8ece8a02eb11f050ec701c0ec_8383813421034673541.PyStanHolder'> returned a result with an error set

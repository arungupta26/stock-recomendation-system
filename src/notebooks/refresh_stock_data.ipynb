# %%
from sklearn import  linear_model
import matplotlib.pyplot as pl

import yfinance as yf
import pandas as pd
import numpy as np
from fbprophet import Prophet
from pathlib import Path
import pickle

#!pip install yfinance

from datetime import date

stock_coefficient_file_name= './../resources/Stock_Coefficients.csv'

# Considering data from 2000 to till date for latest trend
start = '2018-01-01'
end = date.today().strftime("%Y-%m-%d")

# %%
# function1 to get stock list from text file
def get_list(filename):
    # pandas read file into data frame
    stocks = pd.read_csv(filename, header = None)
    stocks[0] = stocks[0].str.upper()
    # convert the data frame to numpy array
    stock_array = stocks.values
    return stock_array

# %%
from pandas_datareader._utils import RemoteDataError

# Considering data from 2018 to 2019 for latest trend
# start = '2018-01-01'
# end = '2022-02-01' #date.today().strftime("%Y-%m-%d")

# function2: get historical data for a specific stock, using symbol as the parameter
def load_stock_data(symbol):
    try:

        df = yf.download(symbol , start , end )
        #web.DataReader(symbol, 'yahoo', start, end)
    except RemoteDataError:
        print("No search result : '" + symbol + "'")
        return float('NaN')
    except KeyError:
        print("Date range not supported : '" + symbol + "'")
        return float('NaN')
    close = df[['Close']]

    # Normalize close value by divided by the base value (the close price of the earliest day) and multiplied by 100
    base = close.iloc[0]['Close']
    # neglect the stocks the initial close price < 25 USD to insure the selected stock value
    if base > 10 :
        close = close.assign(Close = close['Close'] / base * 100)
    return close



from sklearn.model_selection import train_test_split

# function3: build linear regression model for a specific stock
# parameter
# show_statistics: indicate if the statistics are printed
# show_dots: indicate if dots data needed
# show_plot: indacate if the plot is shown

#The coefficient estimates for Ordinary Least Squares rely on the independence of the features.
#When features are correlated and the columns of the design matrix  have an approximately linear dependence,
#the design matrix becomes close to singular and as a result, the least-squares estimate becomes highly sensitive to random errors in the observed target,
#producing a large variance.

def build_linear_regression(symbol, show_statistics = True, show_dots = True, show_plot = True):
    close = load_stock_data(symbol)
    # if the close is not dataframe, return NaN
    if not isinstance(close, pd.DataFrame) :
        return float('NaN')

    # normalize datatime datatype to integer
    # simply converting datetime's to # of days since 2018-04-01 divided by 100
    close.index = (close.index - pd.to_datetime('2019-01-01')).days / 100
    close = close.reset_index()
    train, test= train_test_split(close)

    train_x = train.drop('Close', axis = 1)
    train_y = train[['Close']]
    test_x = test.drop('Close', axis = 1)
    test_y = test[['Close']]

    #call linear regression model
    regr = linear_model.LinearRegression()
    regr.fit(train_x,train_y)

    if show_statistics :
        # The coefficients
        print('Coefficients         ->', regr.coef_[0])
        # The mean squared error
        print("Mean squared error   -> %.2f"
              % np.mean((regr.predict(test_x) - test_y) ** 2))
        # Explained variance score: 1 is perfect prediction
        print('Variance score       -> %.2f' % regr.score(test_x, test_y))
        print('features             ->', 'Date', 'Stock Close Price')

    if show_plot :
        pl.plot(test_x, regr.predict(test_x), label = symbol)
        pl.legend()

        # Plot outputs
        pl.xlabel('Date')
        pl.ylabel('Close Price')
        pl.title('Overall Linear Regression Model')

        if show_dots :
            #pl.title(symbol + ' Linear Regression Model')
            pl.plot(test['Date'], test['Close'], linestyle='none', marker='o')

        pl.xticks(())
        pl.yticks(())
    # return the coefficient representing trend
    return regr.coef_[0][0]

# function4: for each symbol in the text file, caculate the coefficents and record in the original text file
def get_coefficient_dataset(filename, show_statistics = False, show_dots = False, show_plot = False) :
    # load stock list data from text file
    stock_array = get_list(filename)
    # extend the 2D array from N * 1 to N * 2 to make place for putting corresponding coefficient
    stock_array = np.insert(stock_array, 1, values=0, axis=1)

    # caculate coefficient for each symbol and store in the stock_array
    for symbol in stock_array:
        print(symbol)
        coefficient = build_linear_regression(symbol[0], show_statistics, show_dots, show_plot)
        symbol[1] = coefficient
        #break

    # transfer stock_array to dataframe with two columns 'Stock' and 'Coefficient'
    coefficient_data = pd.DataFrame(stock_array)
    coefficient_data.columns = ['Stock', 'Coefficient']

    # store the dataframe to csv file for future using
    coefficient_data.to_csv(stock_coefficient_file_name)
    return coefficient_data

# %%
# function4 using example using stock_list_test.txt
coefficient_data_test = get_coefficient_dataset('./../resources/stock_list.txt')
coefficient_data_test
# Out:
# ['AARTIIND.NS' 0]
# [*********************100%***********************]  1 of 1 completed
# ['ABBOTINDIA.NS' 0]
# [*********************100%***********************]  1 of 1 completed
# ['ACC.NS' 0]
# [*********************100%***********************]  1 of 1 completed
# ['ADANIENT.NS' 0]
# [*********************100%***********************]  1 of 1 completed
# ['ADANIPORTS.NS' 0]
# [*********************100%***********************]  1 of 1 completed
# ['ABFRL.NS' 0]
# [*********************100%***********************]  1 of 1 completed
# ['APLLTD.NS' 0]
# [*********************100%***********************]  1 of 1 completed
# ['ALKEM.NS' 0]
# [*********************100%***********************]  1 of 1 completed
# ['AMARAJABAT.NS' 0]
# [*********************100%***********************]  1 of 1 completed
# ['AMBUJACEM.NS' 0]
# [*********************100%***********************]  1 of 1 completed
# ['APOLLOHOSP.NS' 0]
# [*********************100%***********************]  1 of 1 completed
# ['APOLLOTYRE.NS' 0]
# [*********************100%***********************]  1 of 1 completed
# ['ASHOKLEY.NS' 0]
# [*********************100%***********************]  1 of 1 completed
# ['ASIANPAINT.NS' 0]
# [*********************100%***********************]  1 of 1 completed
# ['ASTRAL.NS' 0]
# [*********************100%***********************]  1 of 1 completed
# ['AUBANK.NS' 0]
# [*********************100%***********************]  1 of 1 completed
# ['AUROPHARMA.NS' 0]
# [*********************100%***********************]  1 of 1 completed
# ['AXISBANK.NS' 0]
# [*********************100%***********************]  1 of 1 completed
# ['BAJAJ-AUTO.NS' 0]
# [*********************100%***********************]  1 of 1 completed
# ['BAJFINANCE.NS' 0]
# [*********************100%***********************]  1 of 1 completed
# ['BAJAJFINSV.NS' 0]
# [*********************100%***********************]  1 of 1 completed
# ['BALKRISIND.NS' 0]
# [*********************100%***********************]  1 of 1 completed
# ['BANDHANBNK.NS' 0]
# [*********************100%***********************]  1 of 1 completed
# ['BANKBARODA.NS' 0]
# [*********************100%***********************]  1 of 1 completed
# ['BATAINDIA.NS' 0]
# [*********************100%***********************]  1 of 1 completed
# ['BERGEPAINT.NS' 0]
# [*********************100%***********************]  1 of 1 completed
# ['BEL.NS' 0]
# [*********************100%***********************]  1 of 1 completed
# ['BHARATFORG.NS' 0]
# [*********************100%***********************]  1 of 1 completed
# ['BPCL.NS' 0]
# [*********************100%***********************]  1 of 1 completed
# ['BHARTIARTL.NS' 0]
# [*********************100%***********************]  1 of 1 completed
# ['BHEL.NS' 0]
# [*********************100%***********************]  1 of 1 completed
# ['BIOCON.NS' 0]
# [*********************100%***********************]  1 of 1 completed
# ['BOSCHLTD.NS' 0]
# [*********************100%***********************]  1 of 1 completed
# ['BRITANNIA.NS' 0]
# [*********************100%***********************]  1 of 1 completed
# ['CADILAHC.NS' 0]
# [*********************100%***********************]  1 of 1 completed
# ['CANFINHOME.NS' 0]
# [*********************100%***********************]  1 of 1 completed
# ['CANBK.NS' 0]
# [*********************100%***********************]  1 of 1 completed
# ['CHOLAFIN.NS' 0]
# [*********************100%***********************]  1 of 1 completed
# ['CIPLA.NS' 0]
# [*********************100%***********************]  1 of 1 completed
# ['CUB.NS' 0]
# [*********************100%***********************]  1 of 1 completed
# ['COALINDIA.NS' 0]
# [*********************100%***********************]  1 of 1 completed
# ['COFORGE.NS' 0]
# [*********************100%***********************]  1 of 1 completed
# ['COLPAL.NS' 0]
# [*********************100%***********************]  1 of 1 completed
# ['CONCOR.NS' 0]
# [*********************100%***********************]  1 of 1 completed
# ['COROMANDEL.NS' 0]
# [*********************100%***********************]  1 of 1 completed
# ['CROMPTON.NS' 0]
# [*********************100%***********************]  1 of 1 completed
# ['CUMMINSIND.NS' 0]
# [*********************100%***********************]  1 of 1 completed
# ['DABUR.NS' 0]
# [*********************100%***********************]  1 of 1 completed
# ['DALBHARAT.NS' 0]
# [*********************100%***********************]  1 of 1 completed
# ['DEEPAKNTR.NS' 0]
# [*********************100%***********************]  1 of 1 completed
# ['DELTACORP.NS' 0]
# [*********************100%***********************]  1 of 1 completed
# ['DIVISLAB.NS' 0]
# [*********************100%***********************]  1 of 1 completed
# ['DIXON.NS' 0]
# [*********************100%***********************]  1 of 1 completed
# ['DLF.NS' 0]
# [*********************100%***********************]  1 of 1 completed
# ['LALPATHLAB.NS' 0]
# [*********************100%***********************]  1 of 1 completed
# ['DRREDDY.NS' 0]
# [*********************100%***********************]  1 of 1 completed
# ['EICHERMOT.NS' 0]
# [*********************100%***********************]  1 of 1 completed
# ['ESCORTS.NS' 0]
# [*********************100%***********************]  1 of 1 completed
# ['EXIDEIND.NS' 0]
# [*********************100%***********************]  1 of 1 completed
# ['FEDERALBNK.NS' 0]
# [*********************100%***********************]  1 of 1 completed
# ['GAIL.NS' 0]
# [*********************100%***********************]  1 of 1 completed
# ['GLENMARK.NS' 0]
# [*********************100%***********************]  1 of 1 completed
# ['GMRINFRA.NS' 0]
# [*********************100%***********************]  1 of 1 completed
# ['GODREJCP.NS' 0]
# [*********************100%***********************]  1 of 1 completed
# ['GODREJPROP.NS' 0]
# [*********************100%***********************]  1 of 1 completed
# ['GRANULES.NS' 0]
# [*********************100%***********************]  1 of 1 completed
# ['GRASIM.NS' 0]
# [*********************100%***********************]  1 of 1 completed
# ['GUJGASLTD.NS' 0]
# [*********************100%***********************]  1 of 1 completed
# ['HAVELLS.NS' 0]
# [*********************100%***********************]  1 of 1 completed
# ['HCLTECH.NS' 0]
# [*********************100%***********************]  1 of 1 completed
# ['HDFCAMC.NS' 0]
# [*********************100%***********************]  1 of 1 completed
# ['HDFCBANK.NS' 0]
# [*********************100%***********************]  1 of 1 completed
# ['HDFCLIFE.NS' 0]
# [*********************100%***********************]  1 of 1 completed
# ['HDFC.NS' 0]
# [*********************100%***********************]  1 of 1 completed
# ['HEROMOTOCO.NS' 0]
# [*********************100%***********************]  1 of 1 completed
# ['HINDALCO.NS' 0]
# [*********************100%***********************]  1 of 1 completed
# ['HAL.NS' 0]
# [*********************100%***********************]  1 of 1 completed
# ['HINDPETRO.NS' 0]
# [*********************100%***********************]  1 of 1 completed
# ['HINDUNILVR.NS' 0]
# [*********************100%***********************]  1 of 1 completed
# ['ICICIBANK.NS' 0]
# [*********************100%***********************]  1 of 1 completed
# ['ICICIGI.NS' 0]
# [*********************100%***********************]  1 of 1 completed
# ['ICICIPRULI.NS' 0]
# [*********************100%***********************]  1 of 1 completed
# ['IDFCFIRSTB.NS' 0]
# [*********************100%***********************]  1 of 1 completed
# ['IBULHSGFIN.NS' 0]
# [*********************100%***********************]  1 of 1 completed
# ['INDIAMART.NS' 0]
# [*********************100%***********************]  1 of 1 completed
# ['IEX.NS' 0]
# [*********************100%***********************]  1 of 1 completed
# ['IOC.NS' 0]
# [*********************100%***********************]  1 of 1 completed
# ['IRCTC.NS' 0]
# [*********************100%***********************]  1 of 1 completed
# ['IGL.NS' 0]
# [*********************100%***********************]  1 of 1 completed
# ['INDUSTOWER.NS' 0]
# [*********************100%***********************]  1 of 1 completed
# ['INDUSINDBK.NS' 0]
# [*********************100%***********************]  1 of 1 completed
# ['NAUKRI.NS' 0]
# [*********************100%***********************]  1 of 1 completed
# ['INFY.NS' 0]
# [*********************100%***********************]  1 of 1 completed
# ['INDIGO.NS' 0]
# [*********************100%***********************]  1 of 1 completed
# ['IPCALAB.NS' 0]
# [*********************100%***********************]  1 of 1 completed
# ['ITC.NS' 0]
# [*********************100%***********************]  1 of 1 completed
# ['JINDALSTEL.NS' 0]
# [*********************100%***********************]  1 of 1 completed
# ['JKCEMENT.NS' 0]
# [*********************100%***********************]  1 of 1 completed
# ['JSWSTEEL.NS' 0]
# [*********************100%***********************]  1 of 1 completed
# ['JUBLFOOD.NS' 0]
# [*********************100%***********************]  1 of 1 completed
# ['KOTAKBANK.NS' 0]
# [*********************100%***********************]  1 of 1 completed
# ['L&TFH.NS' 0]
# [*********************100%***********************]  1 of 1 completed
# ['LTI.NS' 0]
# [*********************100%***********************]  1 of 1 completed
# ['LTTS.NS' 0]
# [*********************100%***********************]  1 of 1 completed
# ['LT.NS' 0]
# [*********************100%***********************]  1 of 1 completed
# ['LICHSGFIN.NS' 0]
# [*********************100%***********************]  1 of 1 completed
# ['LUPIN.NS' 0]
# [*********************100%***********************]  1 of 1 completed
# ['M&MFIN.NS' 0]
# [*********************100%***********************]  1 of 1 completed
# ['MGL.NS' 0]
# [*********************100%***********************]  1 of 1 completed
# ['M&M.NS' 0]
# [*********************100%***********************]  1 of 1 completed
# ['MANAPPURAM.NS' 0]
# [*********************100%***********************]  1 of 1 completed
# ['MARICO.NS' 0]
# [*********************100%***********************]  1 of 1 completed
# ['MARUTI.NS' 0]
# [*********************100%***********************]  1 of 1 completed
# ['MFSL.NS' 0]
# [*********************100%***********************]  1 of 1 completed
# ['METROPOLIS.NS' 0]
# [*********************100%***********************]  1 of 1 completed
# ['MINDTREE.NS' 0]
# [*********************100%***********************]  1 of 1 completed
# ['MOTHERSUMI.NS' 0]
# [*********************100%***********************]  1 of 1 completed
# ['MPHASIS.NS' 0]
# [*********************100%***********************]  1 of 1 completed
# ['MRF.NS' 0]
# [*********************100%***********************]  1 of 1 completed
# ['MCX.NS' 0]
# [*********************100%***********************]  1 of 1 completed
# ['MUTHOOTFIN.NS' 0]
# [*********************100%***********************]  1 of 1 completed
# ['NATIONALUM.NS' 0]
# [*********************100%***********************]  1 of 1 completed
# ['NAVINFLUOR.NS' 0]
# [*********************100%***********************]  1 of 1 completed
# ['NESTLEIND.NS' 0]
# [*********************100%***********************]  1 of 1 completed
# ['NMDC.NS' 0]
# [*********************100%***********************]  1 of 1 completed
# ['NTPC.NS' 0]
# [*********************100%***********************]  1 of 1 completed
# ['OBEROIRLTY.NS' 0]
# [*********************100%***********************]  1 of 1 completed
# ['ONGC.NS' 0]
# [*********************100%***********************]  1 of 1 completed
# ['OFSS.NS' 0]
# [*********************100%***********************]  1 of 1 completed
# ['PAGEIND.NS' 0]
# [*********************100%***********************]  1 of 1 completed
# ['PERSISTENT.NS' 0]
# [*********************100%***********************]  1 of 1 completed
# ['PETRONET.NS' 0]
# [*********************100%***********************]  1 of 1 completed
# ['PFIZER.NS' 0]
# [*********************100%***********************]  1 of 1 completed
# ['PIIND.NS' 0]
# [*********************100%***********************]  1 of 1 completed
# ['PIDILITIND.NS' 0]
# [*********************100%***********************]  1 of 1 completed
# ['PEL.NS' 0]
# [*********************100%***********************]  1 of 1 completed
# ['POLYCAB.NS' 0]
# [*********************100%***********************]  1 of 1 completed
# ['PFC.NS' 0]
# [*********************100%***********************]  1 of 1 completed
# ['POWERGRID.NS' 0]
# [*********************100%***********************]  1 of 1 completed
# ['PNB.NS' 0]
# [*********************100%***********************]  1 of 1 completed
# ['PVR.NS' 0]
# [*********************100%***********************]  1 of 1 completed
# ['RBLBANK.NS' 0]
# [*********************100%***********************]  1 of 1 completed
# ['RECLTD.NS' 0]
# [*********************100%***********************]  1 of 1 completed
# ['RELIANCE.NS' 0]
# [*********************100%***********************]  1 of 1 completed
# ['SBILIFE.NS' 0]
# [*********************100%***********************]  1 of 1 completed
# ['SHREECEM.NS' 0]
# [*********************100%***********************]  1 of 1 completed
# ['SIEMENS.NS' 0]
# [*********************100%***********************]  1 of 1 completed
# ['SRF.NS' 0]
# [*********************100%***********************]  1 of 1 completed
# ['SBIN.NS' 0]
# [*********************100%***********************]  1 of 1 completed
# ['SAIL.NS' 0]
# [*********************100%***********************]  1 of 1 completed
# ['STAR.NS' 0]
# [*********************100%***********************]  1 of 1 completed
# ['SUNPHARMA.NS' 0]
# [*********************100%***********************]  1 of 1 completed
# ['SUNTV.NS' 0]
# [*********************100%***********************]  1 of 1 completed
# ['SYNGENE.NS' 0]
# [*********************100%***********************]  1 of 1 completed
# ['TATACHEM.NS' 0]
# [*********************100%***********************]  1 of 1 completed
# ['TCS.NS' 0]
# [*********************100%***********************]  1 of 1 completed
# ['TATACONSUM.NS' 0]
# [*********************100%***********************]  1 of 1 completed
# ['TATAMOTORS.NS' 0]
# [*********************100%***********************]  1 of 1 completed
# ['TATAPOWER.NS' 0]
# [*********************100%***********************]  1 of 1 completed
# ['TATASTEEL.NS' 0]
# [*********************100%***********************]  1 of 1 completed
# ['TECHM.NS' 0]
# [*********************100%***********************]  1 of 1 completed
# ['INDIACEM.NS' 0]
# [*********************100%***********************]  1 of 1 completed
# ['INDHOTEL.NS' 0]
# [*********************100%***********************]  1 of 1 completed
# ['RAMCOCEM.NS' 0]
# [*********************100%***********************]  1 of 1 completed
# ['TITAN.NS' 0]
# [*********************100%***********************]  1 of 1 completed
# ['TORNTPHARM.NS' 0]
# [*********************100%***********************]  1 of 1 completed
# ['TORNTPOWER.NS' 0]
# [*********************100%***********************]  1 of 1 completed
# ['TRENT.NS' 0]
# [*********************100%***********************]  1 of 1 completed
# ['TVSMOTOR.NS' 0]
# [*********************100%***********************]  1 of 1 completed
# ['ULTRACEMCO.NS' 0]
# [*********************100%***********************]  1 of 1 completed
# ['UBL.NS' 0]
# [*********************100%***********************]  1 of 1 completed
# ['MCDOWELL-N.NS' 0]
# [*********************100%***********************]  1 of 1 completed
# ['UPL.NS' 0]
# [*********************100%***********************]  1 of 1 completed
# ['VEDL.NS' 0]
# [*********************100%***********************]  1 of 1 completed
# ['IDEA.NS' 0]
# [*********************100%***********************]  1 of 1 completed
# ['VOLTAS.NS' 0]
# [*********************100%***********************]  1 of 1 completed
# ['WIPRO.NS' 0]
# [*********************100%***********************]  1 of 1 completed
# ['ZEEL.NS' 0]
# [*********************100%***********************]  1 of 1 completed
#              Stock Coefficient
# 0      AARTIIND.NS   17.329384
# 1    ABBOTINDIA.NS   18.657327
# 2           ACC.NS    2.717577
# 3      ADANIENT.NS  116.067437
# 4    ADANIPORTS.NS    6.515773
# ..             ...         ...
# 173        VEDL.NS    0.394223
# 174        IDEA.NS   -3.621158
# 175      VOLTAS.NS    6.554686
# 176       WIPRO.NS   12.101708
# 177        ZEEL.NS   -4.397908
#
# [178 rows x 2 columns]

# %%
from datetime import date

import datetime



# # Considering data from 2000 to 2022
# start = datetime.datetime(2018, 1, 1)
# end = date.today().strftime("%Y-%m-%d")

stocks = Path('./../resources/stock_list.txt').read_text().split("\n")
index=1
for s in stocks:
    print(s)
    df = yf.download( s, start , end)
    close = df['Close']

    close_df = close.reset_index().rename(columns={'Date':'ds', 'Close':'y'})
    close_df['y'] = np.log(close_df['y'])
    model = Prophet(daily_seasonality=True)
    model.fit(close_df)
    pkl_path = "./../resources/fbprophet/model/"+s+".model"
    with open(pkl_path, "wb") as f:
        pickle.dump(model, f)

    #     # save the dataframe
    #     forecast.to_pickle("./../../resources/fbprophet/forecast/"+s+".forecast")
    print(index,"*** Data Saved for -> ",s)
    index = index+1
# Out:
# AARTIIND.NS
# [*********************100%***********************]  1 of 1 completed
# Initial log joint probability = -2.23477
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#       99       4345.96   0.000629705       576.598           1           1      121
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      199       4374.72   0.000268121       833.207           1           1      234
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      299       4393.01    0.00138763       1133.71           1           1      354
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      399       4401.74   0.000945255       1753.78           1           1      477
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      499       4415.77   0.000318844          1804      0.9174      0.9174      592
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      599       4426.37    0.00432784       732.702           1           1      707
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      699       4428.25   0.000143421       1218.08      0.1515           1      822
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      799       4429.93    0.00604738       2177.82           1           1      934
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      899       4433.72   0.000178614       199.639           1           1     1059
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      999       4434.57   2.86471e-05        114.12           1           1     1183
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#     1099       4435.71   3.46486e-05       912.616     0.02841           1     1297
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#     1199       4436.17   0.000620186       445.706      0.4776           1     1419
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#     1299        4437.7    0.00389238       777.816           1           1     1536
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#     1399        4440.8   0.000118691       245.835           1           1     1658
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#     1499       4441.67   3.28572e-05       617.216      0.1874           1     1777
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#     1544       4441.93   5.83354e-06       245.051   6.936e-08       0.001     1874  LS failed, Hessian reset
#     1599       4442.05   0.000649869       122.095           1           1     1942
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#     1699       4442.28   3.74978e-05       141.981           1           1     2065
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#     1701       4442.28   3.32782e-06       226.046   1.722e-08       0.001     2108  LS failed, Hessian reset
#     1799       4443.21    0.00493813       925.875           1           1     2226
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#     1899       4443.69   2.20298e-05       96.3487           1           1     2348
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#     1970       4443.81   1.65754e-06       79.9642   7.524e-09       0.001     2484  LS failed, Hessian reset
#     1999       4443.85   0.000151049       331.592      0.7342      0.7342     2520
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#     2099       4444.44   0.000449285       334.222       2.363      0.2363     2643
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#     2112       4444.49   1.49637e-06       88.8579   8.279e-09       0.001     2705  LS failed, Hessian reset
#     2140       4444.54   3.23068e-06       209.309   9.148e-09       0.001     2782  LS failed, Hessian reset
#     2199       4444.59   7.38803e-05       144.507           1           1     2855
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#     2299       4444.66   0.000965345       366.689           1           1     2977
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#     2399       4444.86   3.31475e-06       206.696      0.4596      0.4596     3104
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#     2499       4445.12    0.00182232       589.497           1           1     3227
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#     2599       4445.37   2.70897e-05       516.605       0.676       0.676     3341
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#     2648       4445.41   6.50766e-06       197.766   5.379e-08       0.001     3442  LS failed, Hessian reset
#     2699       4445.46    2.1114e-05       268.639      0.4541      0.4541     3501
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#     2706       4445.46   2.17986e-06       143.384   2.093e-08       0.001     3557  LS failed, Hessian reset
#     2775       4445.48   1.72215e-06       116.341   2.086e-08       0.001     3704  LS failed, Hessian reset
#     2799       4445.48   7.72808e-06        66.986      0.5053      0.8143     3731
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#     2803       4445.48   3.60119e-07       54.0774   6.293e-09       0.001     3783  LS failed, Hessian reset
# Optimization terminated normally:
#   Convergence detected: relative gradient magnitude is below tolerance
# 1 *** Data Saved for ->  AARTIIND.NS
# ABBOTINDIA.NS
# [*********************100%***********************]  1 of 1 completed
# Initial log joint probability = -2.34258
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#       99       4788.07   0.000729728       4080.42      0.2161           1      115
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      199       4889.11    0.00813876       5526.29           1           1      224
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      299       4954.65   0.000905797       4324.44           1           1      342
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      399       5051.14    0.00025382       1840.37           1           1      453
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      499       5090.57   0.000587492       3958.69      0.3257      0.3257      564
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      599       5108.16    0.00517341       2708.36           1           1      685
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      699       5127.55   0.000612582       6900.06      0.8737      0.8737      797
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      799       5154.65   0.000236673       4624.82     0.09077           1      911
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      899       5169.77    0.00502293       9173.59           1           1     1031
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      999       5193.53     0.0197617         18340           1           1     1145
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#     1099        5212.6   0.000259285       4885.92      0.1903      0.9245     1262
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#     1199       5221.19   0.000102654       808.047       0.789       0.789     1379
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#     1299        5224.2    0.00188574       1884.55           1           1     1490
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#     1399        5227.3    6.3177e-05       863.184           1           1     1605
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#     1499       5228.14   0.000284133       2012.88           1           1     1717
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#     1599       5230.75    0.00064181       2012.38      0.5892      0.5892     1828
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#     1699       5231.98   0.000307788       2699.88      0.2671      0.2671     1947
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#     1799       5232.75   0.000180199       2520.14           1           1     2063
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#     1899       5233.13   1.44618e-05       310.951      0.4176      0.4176     2177
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#     1999       5233.71   0.000556211       664.431        1.09       0.109     2289
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#     2099       5234.18    0.00015541       784.098           1           1     2400
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#     2199       5235.25    0.00105754       2155.59      0.4758      0.4758     2517
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#     2299       5237.27   0.000616731       1448.53           1           1     2640
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#     2399       5237.74   0.000183783        220.88           1           1     2755
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#     2499        5238.3   0.000103046       287.018           1           1     2871
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#     2599       5238.63   0.000336343       358.538           1           1     2992
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#     2699       5239.74   0.000101329       575.344           1           1     3109
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#     2799       5240.06   2.29833e-05       190.811      0.1124       0.978     3225
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#     2899       5240.15   4.34606e-05       405.002           1           1     3346
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#     2997       5240.26   5.91801e-07        225.39   2.011e-09       0.001     3510  LS failed, Hessian reset
#     2999       5240.26   9.47766e-06       209.986           1           1     3513
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#     3021       5240.31    7.1343e-07       264.117   2.976e-09       0.001     3584  LS failed, Hessian reset
#     3099       5240.37    0.00035255        352.61           1           1     3673
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#     3199       5240.55   0.000225524       416.434           1           1     3786
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#     3299       5241.23    4.2458e-05       1285.63      0.5438      0.5438     3900
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#     3399       5241.39   9.51695e-05       285.631           1           1     4025
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#     3499       5241.56   9.54001e-05       869.868           1           1     4146
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#     3571       5241.68   4.77573e-07       167.288   4.472e-09       0.001     4282  LS failed, Hessian reset
#     3599       5241.72   8.05107e-06       206.415           1           1     4310
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#     3691       5241.78   1.00953e-06       311.786   1.529e-09       0.001     4466  LS failed, Hessian reset
#     3699       5241.79   7.94086e-07       275.718      0.3148      0.3148     4476
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#     3799       5241.83   4.84345e-06       80.3177      0.4766      0.4766     4604
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#     3899       5242.15    0.00184702       1115.22           1           1     4725
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#     3999        5242.6   0.000197168       698.468      0.1584      0.1584     4840
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#     4099       5243.65   3.37039e-05       425.354      0.2023      0.2023     4965
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#     4199       5244.05   0.000129262       247.093           1           1     5081
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#     4299       5244.39   6.03713e-05       388.724           1           1     5195
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#     4399       5244.63   4.73161e-05       1040.83      0.1982      0.1982     5313
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#     4442       5244.65   1.64725e-05       32.3493           1           1     5362
# Optimization terminated normally:
#   Convergence detected: relative gradient magnitude is below tolerance
# 2 *** Data Saved for ->  ABBOTINDIA.NS
# ACC.NS
# [*********************100%***********************]  1 of 1 completed
# Initial log joint probability = -2.58862
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#       99       4380.89   0.000508273       6407.82      0.7908      0.7908      119
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      199       4476.72     0.0104696       4331.05           1           1      229
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      299       4511.76    0.00521126       2084.59           1           1      344
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      399       4592.43    0.00803731       2524.62           1           1      456
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      499       4618.58    0.00127092       1055.94       1.022      0.1022      573
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      599       4646.55    0.00256959       1681.77           1           1      689
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      699       4682.44    0.00358807       13446.7           1           1      807
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      799       4706.16      0.016637        9933.9      0.7341      0.7341      922
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      899       4733.64   0.000320267       1194.79       0.633       0.633     1034
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      999       4745.51    0.00932051       2992.14           1           1     1141
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#     1099       4757.41    0.00110186       1430.61           1           1     1254
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#     1199       4763.47    0.00016502       733.262           1           1     1371
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#     1299       4768.83    0.00107418       915.639           1           1     1488
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#     1399        4778.9    0.00308247       777.614           1           1     1605
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#     1499       4781.11    0.00331884       2292.33           1           1     1714
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#     1599       4782.78   0.000246196       1551.38      0.4452           1     1833
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#     1699       4794.66    0.00177737       1005.63           1           1     1950
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#     1799       4799.86   0.000950722       799.748           1           1     2065
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#     1899       4801.13    0.00122592       496.598           1           1     2177
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#     1999       4803.53   0.000552307       833.062       1.406      0.1406     2293
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#     2099        4807.5   0.000137082       358.689       0.454       0.454     2400
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#     2199       4809.38   4.33849e-05       675.026      0.2047           1     2508
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#     2299       4811.49   0.000271548       834.801           1           1     2619
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#     2399       4812.55    0.00017227       201.653       3.789      0.3789     2736
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#     2499        4813.4    0.00232726       1050.62           1           1     2857
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#     2599       4815.21   0.000112223       1185.68           1           1     2974
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#     2699       4816.63   2.96039e-05       320.507           1           1     3090
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#     2799       4818.38     0.0011519       1131.51           1           1     3202
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#     2899       4819.37   4.07231e-05       705.948      0.1998      0.1998     3319
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#     2999       4820.66   0.000126775       306.264           1           1     3434
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#     3099       4822.78    0.00114472        2785.4           1           1     3552
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#     3199       4824.58    0.00185379       646.618           1           1     3666
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#     3299        4827.9    0.00199384       2536.49           1           1     3780
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#     3399       4828.67   5.49672e-05       275.661           1           1     3896
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#     3499       4829.28    0.00141608       440.632           1           1     4010
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#     3599       4830.22   0.000315232       216.667      0.8722     0.08722     4133
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#     3699       4830.92   2.17484e-05       191.089           1           1     4252
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#     3781       4830.98   4.61201e-07        74.007   9.008e-09       0.001     4398  LS failed, Hessian reset
#     3799       4830.99   2.23839e-05       449.915       0.805       0.805     4417
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#     3882       4831.18   5.76342e-07        115.66   4.612e-09       0.001     4564  LS failed, Hessian reset
#     3899        4831.2   0.000121701       868.385      0.5608      0.5608     4583
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#     3999       4831.28    0.00013897       458.782      0.1777      0.7474     4705
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#     4099       4831.33    3.6906e-06       121.842           1           1     4828
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#     4112       4831.34    1.9645e-05       42.4866           1           1     4841
# Optimization terminated normally:
#   Convergence detected: relative gradient magnitude is below tolerance
# 3 *** Data Saved for ->  ACC.NS
# ADANIENT.NS
# [*********************100%***********************]  1 of 1 completed
# Initial log joint probability = -5.04093
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#       99       3382.31    0.00467418       780.159           1           1      121
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      199       3613.93    0.00283725       2939.78           1           1      235
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      299       3710.47    0.00447345       2714.11           1           1      350
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      399       3808.31     0.0108589       3761.79           1           1      469
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      499       3863.27    0.00738507       1003.55           1           1      584
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      599       3873.12   0.000451036       331.623           1           1      692
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      699       3878.52   0.000368258       395.521           1           1      805
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      755       3891.01   1.42024e-05       446.944    3.68e-08       0.001      912  LS failed, Hessian reset
#      799       3894.87   0.000306698       641.275      0.6772      0.6772      963
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      899       3898.84    0.00348474       1320.49           1           1     1069
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      999       3900.55   0.000359975        198.67           1           1     1186
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#     1099       3903.41    0.00280115       318.715           1           1     1298
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#     1199       3907.82   0.000444868       1600.54     0.04447           1     1412
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#     1299       3910.86    0.00375466       973.343      0.2821           1     1527
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#     1399       3916.25    0.00160057       906.592      0.6507      0.6507     1641
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#     1499       3920.33    0.00205802       1974.12           1           1     1755
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#     1599       3923.21    0.00075237       211.767           1           1     1881
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#     1699       3925.26    0.00155951       364.055           1           1     1999
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#     1799       3926.92   0.000927213       489.407           1           1     2117
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#     1899       3927.53   7.81703e-05       166.713           1           1     2237
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#     1999       3928.17   0.000369399       105.795      0.7986      0.7986     2360
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#     2056       3930.42   6.92606e-06       166.748   1.264e-08       0.001     2486  LS failed, Hessian reset
#     2099       3931.17    0.00442477       632.976       2.258      0.2258     2534
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#     2199       3932.54   0.000159529       96.3678      0.7851      0.7851     2656
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#     2299       3932.84   0.000299885       278.926           1           1     2784
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#     2399       3933.71    0.00287315       697.039           1           1     2901
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#     2499       3934.74   0.000637172       639.444     0.08595           1     3010
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#     2599       3935.47    0.00305645       321.536      0.9138      0.9138     3128
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#     2699       3936.96   0.000474256        523.06           1           1     3241
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#     2799       3937.35   0.000180326       239.294           1           1     3363
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#     2899       3937.63   3.19511e-05       309.403      0.7326      0.7326     3486
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#     2998       3938.28   3.32826e-06        63.559   1.215e-08       0.001     3639  LS failed, Hessian reset
#     2999       3938.28    7.5212e-06       48.8192          10           1     3641
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#     3099       3938.41   0.000123064       74.0405           1           1     3760
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#     3110       3938.42   1.47217e-05       292.367   1.681e-07       0.001     3816  LS failed, Hessian reset
#     3144       3938.43   2.93603e-06       119.807   2.367e-08       0.001     3914  LS failed, Hessian reset
#     3199       3938.65   0.000626061       499.091      0.9317      0.9317     3977
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#     3285        3939.7   3.39084e-06       141.167   2.033e-08       0.001     4129  LS failed, Hessian reset
#     3299       3939.78   3.08931e-05       204.311      0.6097      0.6097     4146
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#     3399       3940.11   0.000255409       212.055           1           1     4260
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#     3499       3940.44   2.28367e-05       123.913       1.778      0.1778     4397
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#     3599       3940.59   8.68126e-05       72.6847           1           1     4520
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#     3615        3940.6   1.34945e-05       122.125   1.124e-07       0.001     4585  LS failed, Hessian reset
#     3646       3940.61   1.89885e-06        68.532   2.675e-08       0.001     4666  LS failed, Hessian reset
#     3699       3940.72   0.000480472       313.965           1           1     4726
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#     3799       3940.84   0.000101969       123.474           1           1     4853
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#     3899       3940.94   9.88945e-05       105.867           1           1     4987
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#     3943          3941   1.54558e-06       66.1641   2.298e-08       0.001     5086  LS failed, Hessian reset
#     3999       3941.03   0.000152666       289.126      0.6338      0.6338     5155
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#     4099       3942.25      0.011328       662.199           1           1     5262
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#     4199       3943.86    0.00137869       388.223           1           1     5376
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#     4299       3945.22   0.000204002       459.158      0.3915           1     5495
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#     4399       3945.73   5.18683e-05       93.9451           1           1     5608
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#     4499       3945.86   0.000296426         268.9           1           1     5737
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#     4573       3946.01   1.67748e-06       71.6826    3.04e-08       0.001     5859  LS failed, Hessian reset
#     4599       3946.03   7.88495e-06       55.6979       2.116      0.5257     5893
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#     4657        3946.1   7.01254e-06       240.441   4.209e-08       0.001     6016  LS failed, Hessian reset
#     4699       3946.14   5.50222e-05       63.1716           1           1     6065
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#     4710       3946.14   4.75452e-06       40.2901   1.031e-07       0.001     6117  LS failed, Hessian reset
#     4785       3946.16   3.60672e-05       180.743   4.721e-07       0.001     6263  LS failed, Hessian reset
#     4799       3946.16   2.34728e-06       52.0845         2.2      0.5838     6281
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#     4802       3946.16   1.00697e-08       48.1243    0.001085           1     6291
# Optimization terminated normally:
#   Convergence detected: relative change in objective function was below tolerance
# 4 *** Data Saved for ->  ADANIENT.NS
# ADANIPORTS.NS
# [*********************100%***********************]  1 of 1 completed
# Initial log joint probability = -3.11772
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#       99       4052.12     0.0166161       4597.56           1           1      124
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      199       4155.21    0.00164892       1209.14      0.9005      0.9005      242
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      299       4208.14     0.0137355       6226.26           1           1      357
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      399       4276.22     0.0124558       2039.51           1           1      469
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      499       4300.06    0.00159268       3522.68      0.4086      0.4086      585
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      599       4312.31    0.00691992       607.766           1           1      695
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      699       4322.01    0.00115012       800.065      0.2104           1      806
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      799       4333.11    0.00587471       886.133           1           1      924
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      899       4349.02   0.000639139       814.666           1           1     1039
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      999       4362.51    0.00215177       2449.31           1           1     1159
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#     1099       4376.07    0.00150855        616.69           1           1     1272
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#     1199       4381.11    0.00012172       501.656      0.4318      0.4318     1388
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#     1299       4387.07    0.00138433       2785.18      0.2811      0.2811     1503
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#     1399       4393.44    0.00107523       1079.78      0.8856      0.8856     1619
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#     1499       4398.98    0.00040261       332.413           1           1     1726
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#     1599       4402.35     0.0075181       7109.68      0.3737      0.3737     1832
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#     1699       4406.38    0.00120672       655.587           1           1     1953
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#     1799       4410.86    0.00306101       1144.35           1           1     2069
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#     1899       4412.75    0.00109843       2617.08           1           1     2185
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#     1999       4414.53   0.000779666       623.869           1           1     2298
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#     2099       4415.39   0.000418762       2013.59     0.01525           1     2409
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#     2199       4416.35   0.000246001       378.476      0.8563      0.8563     2529
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#     2299       4417.05   0.000276295       137.152           1           1     2657
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#     2363       4417.35   4.51324e-06       286.367   2.288e-08       0.001     2790  LS failed, Hessian reset
#     2399       4417.42    7.2294e-05       593.212      0.6176      0.6176     2832
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#     2407       4417.43   1.41737e-06       76.5944   6.353e-09       0.001     2888  LS failed, Hessian reset
#     2499       4417.71   0.000186869       91.9761           1           1     3000
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#     2599       4418.49    0.00251281        858.03      0.5429      0.5429     3123
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#     2699       4422.61    0.00615774       1614.08      0.2598      0.2598     3238
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#     2799       4426.12    0.00207611       1070.85           1           1     3347
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#     2899       4427.89    0.00436571       928.865           1           1     3466
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#     2999       4429.28   4.49906e-05       158.343           1           1     3584
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#     3099       4430.21   3.14392e-05       392.453      0.4538      0.4538     3702
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#     3199       4430.55   0.000282455       320.652      0.3293     0.03293     3827
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#     3222        4430.6   1.18627e-05       101.182   1.257e-07       0.001     3893  LS failed, Hessian reset
#     3299       4430.76   1.63634e-05       379.599      0.3966      0.3966     3980
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#     3301       4430.77   2.32096e-06       149.488   2.893e-08       0.001     4026  LS failed, Hessian reset
#     3399       4430.99   8.18963e-05       291.513      0.2287           1     4163
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#     3484        4431.5   2.11423e-06       128.776   5.667e-09       0.001     4341  LS failed, Hessian reset
#     3499       4431.54   0.000430694        384.53           1           1     4358
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#     3599       4431.81   3.36581e-05       114.587           1           1     4476
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#     3699       4431.91   0.000147239       113.826      0.3649           1     4596
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#     3799       4431.94   2.70729e-05       160.081       2.042      0.2042     4717
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#     3851       4431.95   3.73678e-07       52.1148      0.3333           1     4791
# Optimization terminated normally:
#   Convergence detected: relative gradient magnitude is below tolerance
# 5 *** Data Saved for ->  ADANIPORTS.NS
# ABFRL.NS
# [*********************100%***********************]  1 of 1 completed
# Initial log joint probability = -3.48958
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#       99       3701.48     0.0187361       3654.74           1           1      122
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      199       3762.23      0.044486       4206.06           1           1      236
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      299       3851.32     0.0055822       2310.57           1           1      349
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      399       3870.13   0.000712008       328.241           1           1      468
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      499       3893.47    0.00105999       668.966           1           1      581
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      599       3907.36   0.000366343        482.82           1           1      696
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      699       3927.43    0.00446716       1860.62           1           1      807
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      799       3953.19    0.00473262       691.752           1           1      926
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      899       3967.32     0.0051761       1616.34           1           1     1036
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      999       3980.45    0.00061989       1370.81           1           1     1146
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#     1099       3986.22   0.000132387       772.615           1           1     1261
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#     1199       3989.95   0.000496488       387.904           1           1     1372
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#     1299       4001.74   0.000391833       1102.92           1           1     1487
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#     1399       4009.16   0.000835485       1312.12      0.1542           1     1597
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#     1499        4011.2   0.000146423       150.917      0.4946      0.4946     1714
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#     1599       4011.97   0.000518896       147.612      0.4188     0.04188     1845
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#     1699       4013.64   0.000163405       322.242           1           1     1972
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#     1761       4014.07   5.36793e-06       198.403   1.939e-08       0.001     2086  LS failed, Hessian reset
#     1799       4014.55   7.76819e-05       190.674       1.729      0.1729     2133
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#     1899       4015.31   6.54003e-05       290.842      0.9163      0.9163     2247
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#     1999       4016.28   0.000613384       403.816           1           1     2368
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#     2099       4016.94   6.52116e-05       139.942           1           1     2497
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#     2110       4016.96   4.04357e-05       151.155    6.31e-07       0.001     2551  LS failed, Hessian reset
#     2198       4017.12    2.8159e-06       99.6078    1.76e-08       0.001     2717  LS failed, Hessian reset
#     2199       4017.12   1.48815e-05       83.3808          10           1     2719
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#     2299       4017.45     0.0027371          1333           1           1     2839
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#     2399       4020.67   0.000680243       736.539       0.507       0.507     2953
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#     2499       4021.47   0.000341207       237.808       6.357      0.6357     3076
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#     2511       4021.51   6.79629e-06       218.418    1.52e-08       0.001     3129  LS failed, Hessian reset
#     2538       4021.58   2.73619e-06       104.909   1.847e-08       0.001     3205  LS failed, Hessian reset
#     2588        4021.7   8.97547e-06       336.407   1.834e-08       0.001     3328  LS failed, Hessian reset
#     2599       4021.77   0.000150149       88.0158      0.8054      0.8054     3343
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#     2636       4021.81   5.23231e-06       173.409   4.598e-08       0.001     3435  LS failed, Hessian reset
#     2672       4021.82   5.83743e-06       173.718   6.799e-08       0.001     3526  LS failed, Hessian reset
#     2699       4021.82   1.01654e-05       81.5051       2.067      0.5283     3560
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#     2799       4022.09    0.00117794       571.899     0.03421      0.7672     3675
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#     2899       4022.62   0.000747444       362.233      0.7024           1     3799
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#     2900       4022.62   7.53654e-06       285.214   2.081e-08       0.001     3848  LS failed, Hessian reset
#     2999       4022.75   4.85372e-05       145.602           1           1     3965
# ...
#     5347       4607.55   8.77784e-07       37.0961      0.7602      0.7602     6312
# Optimization terminated normally:
#   Convergence detected: relative gradient magnitude is below tolerance
# 176 *** Data Saved for ->  VOLTAS.NS
# WIPRO.NS
# [*********************100%***********************]  1 of 1 completed
# Initial log joint probability = -3.06053
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#       99       4121.92     0.0126494       2752.42           1           1      121
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      199       4250.85   0.000657372       3120.99           1           1      237
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      299       4381.67   0.000950864       1160.27           1           1      351
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      399        4483.9    0.00193076       2486.23           1           1      458
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      499       4519.57    0.00521079        4007.7       1.932      0.1932      574
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      599       4561.79    0.00138304       1092.69      0.8462      0.8462      689
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      699       4585.37   6.06196e-05       345.624           1           1      803
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      799       4593.68   4.04824e-05       723.513           1           1      912
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      899       4595.33   0.000452296       935.938           1           1     1022
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      999       4607.74    0.00539629       852.057           1           1     1136
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#     1099       4609.89   0.000670109       1911.82           1           1     1254
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#     1199       4611.82   0.000284147       414.277           1           1     1364
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#     1299       4616.96    0.00129972        532.93           1           1     1479
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#     1399       4619.03    0.00204401       527.074           1           1     1594
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#     1499       4620.54   2.47976e-05       964.924      0.5662      0.5662     1716
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#     1599        4621.3   0.000647822       918.208      0.4551           1     1830
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#     1699       4627.36   0.000944951       1834.98           1           1     1940
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#     1799       4628.51    0.00059932       1808.65           1           1     2050
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#     1899       4629.69    0.00163419       1772.25           1           1     2166
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#     1999        4630.6   0.000949461       2345.84           1           1     2275
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#     2099       4632.25   0.000390284        678.02       2.114      0.2114     2392
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#     2199       4633.58   0.000796641       1128.43      0.7004      0.7004     2507
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#     2269       4637.09   4.46035e-06       525.559   1.124e-08       0.001     2631  LS failed, Hessian reset
#     2299       4637.51   0.000207876       203.143           1           1     2671
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#     2386       4637.95   5.18788e-06       581.232   1.171e-08       0.001     2827  LS failed, Hessian reset
#     2399       4638.13   0.000111165       948.364           1           1     2841
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#     2499        4638.4   0.000303793        569.76      0.7611      0.7611     2952
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#     2580       4638.49   9.32435e-07       116.645   6.761e-09       0.001     3095  LS failed, Hessian reset
#     2599        4638.5   4.80034e-06       85.8768           1           1     3118
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#     2699        4639.2   0.000720763       181.676           1           1     3233
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#     2799       4639.97   0.000131832       470.164           1           1     3352
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#     2812          4640    8.6245e-06       530.856   5.499e-08       0.001     3424  LS failed, Hessian reset
#     2899       4640.43   0.000128144       268.165           1           1     3535
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#     2956       4640.48   6.00109e-07       72.0455   5.453e-09       0.001     3649  LS failed, Hessian reset
#     2968       4640.49   8.24861e-07       95.0221    1.19e-08       0.001     3706  LS failed, Hessian reset
#     2999       4640.51   9.82379e-05       855.789      0.4266      0.4266     3742
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#     3007       4640.53   8.81239e-06       481.492   4.251e-08       0.001     3792  LS failed, Hessian reset
#     3099       4640.68   0.000109705       236.176           1           1     3905
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#     3199       4641.11   0.000238705       298.542           1           1     4024
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#     3299       4641.55   0.000196829       272.393           1           1     4139
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#     3399       4641.91   1.72572e-05       206.446      0.1201           1     4265
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#     3495       4642.03   5.12999e-07       64.7159   5.926e-09       0.001     4412  LS failed, Hessian reset
#     3499       4642.03   1.90513e-05       138.991      0.9825      0.9825     4417
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#     3599       4642.25   0.000168444       431.776           1           1     4541
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#     3645       4642.31   8.52475e-07       98.2951   1.431e-08       0.001     4643  LS failed, Hessian reset
#     3692       4642.34   1.08903e-05       332.767   1.698e-07       0.001     4750  LS failed, Hessian reset
#     3699       4642.34   1.08343e-05       71.4286           1           1     4757
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#     3734       4642.38   2.03043e-06       152.303   4.174e-09       0.001     4847  LS failed, Hessian reset
#     3799       4642.44   4.02665e-06       67.5001           1           1     4931
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#     3806       4642.44   1.15527e-06       98.3852   4.326e-09       0.001     4985  LS failed, Hessian reset
#     3881       4642.47   4.69808e-06       94.5321   5.141e-08       0.001     5128  LS failed, Hessian reset
#     3899       4642.48   5.17642e-05       132.637           1           1     5153
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#     3999       4642.52   6.98504e-05       122.786           1           1     5266
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#     4099       4642.74   0.000149347       251.398           1           1     5388
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#     4141       4642.75   9.69499e-07       100.938   4.812e-09       0.001     5488  LS failed, Hessian reset
#     4159       4642.75   6.88549e-07       84.4962   1.153e-08       0.001     5561  LS failed, Hessian reset
#     4163       4642.75   1.84441e-07        43.712      0.2602           1     5566
# Optimization terminated normally:
#   Convergence detected: relative gradient magnitude is below tolerance
# 177 *** Data Saved for ->  WIPRO.NS
# ZEEL.NS
# [*********************100%***********************]  1 of 1 completed
# Initial log joint probability = -4.17586
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#       99       3588.18    0.00220644       551.974      0.8466      0.8466      121
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      199        3644.9    0.00123015       960.447      0.8175      0.8175      234
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      299       3659.51     0.0033614       1156.93       1.835      0.1835      343
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      399       3665.96   0.000350426       138.223           1           1      460
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      499       3668.98   0.000976575           318           1           1      579
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      599       3673.85    0.00168585       212.344      0.8704      0.8704      699
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      699       3677.23   0.000599447       345.152      0.9766      0.9766      811
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      799       3679.21   0.000976359       252.052           1           1      929
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      804       3679.48   2.88427e-05       431.797   4.342e-08       0.001      984  LS failed, Hessian reset
#      895       3680.16   9.55622e-06       145.899   9.311e-08       0.001     1143  LS failed, Hessian reset
#      899       3680.23    0.00119973       503.325           1           1     1148
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      920       3680.37   1.64957e-05       202.728    1.61e-07       0.001     1210  LS failed, Hessian reset
#      937       3680.43   6.23735e-06       102.946   6.187e-08       0.001     1278  LS failed, Hessian reset
#      994       3680.67   1.36726e-05       180.294   3.761e-08       0.001     1403  LS failed, Hessian reset
#      999       3680.72   7.34069e-05       92.2751      0.5993      0.5993     1410
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#     1099       3681.08    0.00184629       115.377           1           1     1542
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#     1117       3681.69    5.6822e-05       283.317   7.549e-07       0.001     1612  LS failed, Hessian reset
#     1198       3682.57   5.36998e-06       85.6793    6.26e-08       0.001     1760  LS failed, Hessian reset
#     1199       3682.57    3.8035e-06       76.0043           1           1     1761
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#     1234       3682.68   1.85596e-05       270.198   4.144e-08       0.001     1850  LS failed, Hessian reset
#     1256       3682.78   5.01791e-06       83.0958   5.968e-08       0.001     1925  LS failed, Hessian reset
#     1293       3682.86   8.57176e-06        140.02   6.611e-08       0.001     2020  LS failed, Hessian reset
#     1299       3682.89   2.66566e-05       207.504      0.5539      0.5539     2027
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#     1399        3683.2   0.000130969       187.215           1           1     2150
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#     1437       3684.95   4.63268e-05       582.533   3.432e-08       0.001     2236  LS failed, Hessian reset
#     1499       3687.25   0.000857427        189.68           1           1     2311
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#     1599       3687.63   8.70415e-05        144.43           1           1     2445
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#     1661       3687.82   1.19487e-05       187.912   8.127e-08       0.001     2565  LS failed, Hessian reset
#     1699       3687.85     3.966e-05       97.8504           1           1     2607
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#     1785        3688.5   2.09636e-05       198.342   3.085e-08       0.001     2768  LS failed, Hessian reset
#     1799       3688.91    0.00135581       444.042       2.199      0.2199     2787
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#     1806       3688.96   1.22299e-05       113.643   3.072e-08       0.001     2844  LS failed, Hessian reset
#     1851       3689.34   1.16455e-05       170.966   8.097e-08       0.001     2937  LS failed, Hessian reset
#     1899       3689.41   4.08932e-06       77.2695      0.3936      0.3936     3014
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#     1928       3689.42   2.73229e-05       160.571   3.287e-07       0.001     3092  LS failed, Hessian reset
#     1999       3689.55   0.000475052       339.223      0.2526           1     3187
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#     2099       3689.77   2.04596e-05       49.9951      0.8279      0.8279     3319
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#     2160       3689.82   5.95235e-06       99.4725   4.377e-08       0.001     3440  LS failed, Hessian reset
#     2199       3689.83   1.71584e-06       52.2292     0.06284           1     3493
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#     2204       3689.83   2.87296e-07        49.084      0.3595           1     3501
# Optimization terminated normally:
#   Convergence detected: relative gradient magnitude is below tolerance
# 178 *** Data Saved for ->  ZEEL.NS

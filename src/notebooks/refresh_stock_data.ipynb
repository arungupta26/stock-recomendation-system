# %%
from sklearn import  linear_model
import matplotlib.pyplot as pl

import yfinance as yf
import pandas as pd
import numpy as np
from fbprophet import Prophet
from pathlib import Path
import pickle

#!pip install yfinance

from datetime import date

stock_coefficient_file_name= './../resources/Stock_Coefficients.csv'

# Considering data from 2000 to till date for latest trend
start = '2018-01-01'
end = date.today().strftime("%Y-%m-%d")
#end = '2022-02-05'

# %%
# function1 to get stock list from text file
def get_list(filename):
    # pandas read file into data frame
    stocks = pd.read_csv(filename, header = None)
    stocks[0] = stocks[0].str.upper()
    # convert the data frame to numpy array
    stock_array = stocks.values
    return stock_array

# %%
from pandas_datareader._utils import RemoteDataError

# Considering data from 2018 to 2019 for latest trend
# start = '2018-01-01'
# end = '2022-02-01' #date.today().strftime("%Y-%m-%d")

# function2: get historical data for a specific stock, using symbol as the parameter
def load_stock_data(symbol):
    try:

        df = yf.download(symbol , start , end )
        #web.DataReader(symbol, 'yahoo', start, end)
    except RemoteDataError:
        print("No search result : '" + symbol + "'")
        return float('NaN')
    except KeyError:
        print("Date range not supported : '" + symbol + "'")
        return float('NaN')
    close = df[['Close']]

    # Normalize close value by divided by the base value (the close price of the earliest day) and multiplied by 100
    base = close.iloc[0]['Close']
    # neglect the stocks the initial close price < 25 USD to insure the selected stock value
    if base > 10 :
        close = close.assign(Close = close['Close'] / base * 100)
    return close



from sklearn.model_selection import train_test_split

# function3: build linear regression model for a specific stock
# parameter
# show_statistics: indicate if the statistics are printed
# show_dots: indicate if dots data needed
# show_plot: indacate if the plot is shown

#The coefficient estimates for Ordinary Least Squares rely on the independence of the features.
#When features are correlated and the columns of the design matrix  have an approximately linear dependence,
#the design matrix becomes close to singular and as a result, the least-squares estimate becomes highly sensitive to random errors in the observed target,
#producing a large variance.

def build_linear_regression(symbol, show_statistics = True, show_dots = True, show_plot = True):
    close = load_stock_data(symbol)
    # if the close is not dataframe, return NaN

    if not isinstance(close, pd.DataFrame) :
        return float('NaN')

    # normalize datatime datatype to integer
    # simply converting datetime's to # of days since 2018-04-01 divided by 100
    close.index = (close.index - pd.to_datetime('2019-01-01')).days / 100
    close = close.reset_index()
    train, test= train_test_split(close)

    train_x = train.drop('Close', axis = 1)
    train_y = train[['Close']]
    test_x = test.drop('Close', axis = 1)
    test_y = test[['Close']]

    #call linear regression model
    regr = linear_model.LinearRegression()
    regr.fit(train_x,train_y)

    if show_statistics :
        # The coefficients
        print('Coefficients         ->', regr.coef_[0])
        # The mean squared error
        print("Mean squared error   -> %.2f"
              % np.mean((regr.predict(test_x) - test_y) ** 2))
        # Explained variance score: 1 is perfect prediction
        print('Variance score       -> %.2f' % regr.score(test_x, test_y))
        print('features             ->', 'Date', 'Stock Close Price')

    if show_plot :
        pl.plot(test_x, regr.predict(test_x), label = symbol)
        pl.legend()

        # Plot outputs
        pl.xlabel('Date')
        pl.ylabel('Close Price')
        pl.title('Overall Linear Regression Model')

        if show_dots :
            #pl.title(symbol + ' Linear Regression Model')
            pl.plot(test['Date'], test['Close'], linestyle='none', marker='o')

        pl.xticks(())
        pl.yticks(())
    # return the coefficient representing trend
    return regr.coef_[0][0]

# function4: for each symbol in the text file, caculate the coefficents and record in the original text file
def get_coefficient_dataset(filename, show_statistics = False, show_dots = False, show_plot = False) :
    # load stock list data from text file
    stock_array = get_list(filename)
    # extend the 2D array from N * 1 to N * 2 to make place for putting corresponding coefficient
    stock_array = np.insert(stock_array, 1, values=0, axis=1)
    stock_array = np.insert(stock_array, 1, values=0, axis=1)

    # caculate coefficient for each symbol and store in the stock_array
    for symbol in stock_array:
        print(symbol)
        coefficient  = build_linear_regression(symbol[0], show_statistics, show_dots, show_plot)
        symbol[1] = coefficient


        df = yf.download(symbol[0] , start , end )
        lastData = df[-2:]['Close']
        deltaPercentage = (lastData[1]-lastData[0]) / lastData[1] * 100
        symbol[2] = deltaPercentage


        # break

    # transfer stock_array to dataframe with two columns 'Stock' and 'Coefficient'
    coefficient_data = pd.DataFrame(stock_array)

    coefficient_data.columns = ['Stock', 'Coefficient', 'LastDayChange']


    # store the dataframe to csv file for future using
    coefficient_data.to_csv(stock_coefficient_file_name)
    return coefficient_data

# %%
# function4 using example using stock_list_test.txt
coefficient_data_test = get_coefficient_dataset('./../resources/stock_list.txt')
coefficient_data_test
# Out:
# ['AARTIIND.NS' 0 0]
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# ['ABBOTINDIA.NS' 0 0]
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# ['ACC.NS' 0 0]
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# ['ADANIENT.NS' 0 0]
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# ['ADANIPORTS.NS' 0 0]
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# ['ABFRL.NS' 0 0]
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# ['APLLTD.NS' 0 0]
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# ['ALKEM.NS' 0 0]
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# ['AMARAJABAT.NS' 0 0]
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# ['AMBUJACEM.NS' 0 0]
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# ['APOLLOHOSP.NS' 0 0]
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# ['APOLLOTYRE.NS' 0 0]
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# ['ASHOKLEY.NS' 0 0]
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# ['ASIANPAINT.NS' 0 0]
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# ['ASTRAL.NS' 0 0]
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# ['AUBANK.NS' 0 0]
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# ['AUROPHARMA.NS' 0 0]
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# ['AXISBANK.NS' 0 0]
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# ['BAJAJ-AUTO.NS' 0 0]
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# ['BAJFINANCE.NS' 0 0]
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# ['BAJAJFINSV.NS' 0 0]
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# ['BALKRISIND.NS' 0 0]
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# ['BANDHANBNK.NS' 0 0]
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# ['BANKBARODA.NS' 0 0]
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# ['BATAINDIA.NS' 0 0]
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# ['BERGEPAINT.NS' 0 0]
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# ['BEL.NS' 0 0]
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# ['BHARATFORG.NS' 0 0]
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# ['BPCL.NS' 0 0]
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# ['BHARTIARTL.NS' 0 0]
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# ['BHEL.NS' 0 0]
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# ['BIOCON.NS' 0 0]
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# ['BOSCHLTD.NS' 0 0]
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# ['BRITANNIA.NS' 0 0]
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# ['CADILAHC.NS' 0 0]
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# ['CANFINHOME.NS' 0 0]
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# ['CANBK.NS' 0 0]
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# ['CHOLAFIN.NS' 0 0]
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# ['CIPLA.NS' 0 0]
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# ['CUB.NS' 0 0]
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# ['COALINDIA.NS' 0 0]
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# ['COFORGE.NS' 0 0]
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# ['COLPAL.NS' 0 0]
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# ['CONCOR.NS' 0 0]
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# ['COROMANDEL.NS' 0 0]
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# ['CROMPTON.NS' 0 0]
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# ['CUMMINSIND.NS' 0 0]
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# ['DABUR.NS' 0 0]
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# ['DALBHARAT.NS' 0 0]
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# ['DEEPAKNTR.NS' 0 0]
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# ['DELTACORP.NS' 0 0]
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# ['DIVISLAB.NS' 0 0]
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# ['DIXON.NS' 0 0]
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# ['DLF.NS' 0 0]
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# ['LALPATHLAB.NS' 0 0]
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# ['DRREDDY.NS' 0 0]
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# ['EICHERMOT.NS' 0 0]
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# ['ESCORTS.NS' 0 0]
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# ['EXIDEIND.NS' 0 0]
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# ['FEDERALBNK.NS' 0 0]
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# ['GAIL.NS' 0 0]
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# ['GLENMARK.NS' 0 0]
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# ['GMRINFRA.NS' 0 0]
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# ['GODREJCP.NS' 0 0]
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# ['GODREJPROP.NS' 0 0]
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# ['GRANULES.NS' 0 0]
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# ['GRASIM.NS' 0 0]
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# ['GUJGASLTD.NS' 0 0]
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# ['HAVELLS.NS' 0 0]
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# ['HCLTECH.NS' 0 0]
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# ['HDFCAMC.NS' 0 0]
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# ['HDFCBANK.NS' 0 0]
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# ['HDFCLIFE.NS' 0 0]
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# ['HDFC.NS' 0 0]
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# ['HEROMOTOCO.NS' 0 0]
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# ['HINDALCO.NS' 0 0]
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# ['HAL.NS' 0 0]
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# ['HINDPETRO.NS' 0 0]
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# ['HINDUNILVR.NS' 0 0]
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# ['ICICIBANK.NS' 0 0]
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# ['ICICIGI.NS' 0 0]
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# ['ICICIPRULI.NS' 0 0]
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# ['IDFCFIRSTB.NS' 0 0]
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# ['IBULHSGFIN.NS' 0 0]
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# ['INDIAMART.NS' 0 0]
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# ['IEX.NS' 0 0]
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# ['IOC.NS' 0 0]
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# ['IRCTC.NS' 0 0]
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# ['IGL.NS' 0 0]
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# ['INDUSTOWER.NS' 0 0]
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# ['INDUSINDBK.NS' 0 0]
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# ['NAUKRI.NS' 0 0]
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# ['INFY.NS' 0 0]
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# ['INDIGO.NS' 0 0]
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# ['IPCALAB.NS' 0 0]
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# ['ITC.NS' 0 0]
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# ['JINDALSTEL.NS' 0 0]
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# ['JKCEMENT.NS' 0 0]
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# ['JSWSTEEL.NS' 0 0]
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# ['JUBLFOOD.NS' 0 0]
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# ['KOTAKBANK.NS' 0 0]
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# ['L&TFH.NS' 0 0]
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# ['LTI.NS' 0 0]
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# ['LTTS.NS' 0 0]
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# ['LT.NS' 0 0]
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# ['LICHSGFIN.NS' 0 0]
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# ['LUPIN.NS' 0 0]
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# ['M&MFIN.NS' 0 0]
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# ['MGL.NS' 0 0]
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# ['M&M.NS' 0 0]
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# ['MANAPPURAM.NS' 0 0]
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# ['MARICO.NS' 0 0]
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# ['MARUTI.NS' 0 0]
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# ['MFSL.NS' 0 0]
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# ['METROPOLIS.NS' 0 0]
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# ['MINDTREE.NS' 0 0]
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# ['MOTHERSUMI.NS' 0 0]
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# ['MPHASIS.NS' 0 0]
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# ['MRF.NS' 0 0]
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# ['MCX.NS' 0 0]
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# ['MUTHOOTFIN.NS' 0 0]
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# ['NATIONALUM.NS' 0 0]
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# ['NAVINFLUOR.NS' 0 0]
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# ['NESTLEIND.NS' 0 0]
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# ['NMDC.NS' 0 0]
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# ['NTPC.NS' 0 0]
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# ['OBEROIRLTY.NS' 0 0]
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# ['ONGC.NS' 0 0]
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# ['OFSS.NS' 0 0]
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# ['PAGEIND.NS' 0 0]
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# ['PERSISTENT.NS' 0 0]
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# ['PETRONET.NS' 0 0]
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# ['PFIZER.NS' 0 0]
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# ['PIIND.NS' 0 0]
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# ['PIDILITIND.NS' 0 0]
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# ['PEL.NS' 0 0]
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# ['POLYCAB.NS' 0 0]
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# ['PFC.NS' 0 0]
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# ['POWERGRID.NS' 0 0]
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# ['PNB.NS' 0 0]
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# ['PVR.NS' 0 0]
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# ['RBLBANK.NS' 0 0]
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# ['RECLTD.NS' 0 0]
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# ['RELIANCE.NS' 0 0]
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# ['SBILIFE.NS' 0 0]
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# ['SHREECEM.NS' 0 0]
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# ['SIEMENS.NS' 0 0]
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# ['SRF.NS' 0 0]
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# ['SBIN.NS' 0 0]
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# ['SAIL.NS' 0 0]
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# ['STAR.NS' 0 0]
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# ['SUNPHARMA.NS' 0 0]
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# ['SUNTV.NS' 0 0]
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# ['SYNGENE.NS' 0 0]
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# ['TATACHEM.NS' 0 0]
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# ['TCS.NS' 0 0]
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# ['TATACONSUM.NS' 0 0]
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# ['TATAMOTORS.NS' 0 0]
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# ['TATAPOWER.NS' 0 0]
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# ['TATASTEEL.NS' 0 0]
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# ['TECHM.NS' 0 0]
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# ['INDIACEM.NS' 0 0]
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# ['INDHOTEL.NS' 0 0]
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# ['RAMCOCEM.NS' 0 0]
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# ['TITAN.NS' 0 0]
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# ['TORNTPHARM.NS' 0 0]
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# ['TORNTPOWER.NS' 0 0]
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# ['TRENT.NS' 0 0]
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# ['TVSMOTOR.NS' 0 0]
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# ['ULTRACEMCO.NS' 0 0]
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# ['UBL.NS' 0 0]
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# ['MCDOWELL-N.NS' 0 0]
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# ['UPL.NS' 0 0]
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# ['VEDL.NS' 0 0]
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# ['IDEA.NS' 0 0]
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# ['VOLTAS.NS' 0 0]
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# ['WIPRO.NS' 0 0]
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# ['ZEEL.NS' 0 0]
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
#              Stock Coefficient LastDayChange
# 0      AARTIIND.NS   17.384509     -3.498201
# 1    ABBOTINDIA.NS   18.727664     -0.471361
# 2           ACC.NS    2.685328     -2.409583
# 3      ADANIENT.NS  113.868362     -1.235613
# 4    ADANIPORTS.NS    6.450623     -1.015611
# ..             ...         ...           ...
# 173        VEDL.NS    0.345374      -0.38355
# 174        IDEA.NS   -3.557557     -3.240735
# 175      VOLTAS.NS     6.72027     -3.895827
# 176       WIPRO.NS   11.786684     -2.172947
# 177        ZEEL.NS   -4.381651     -0.725465
#
# [178 rows x 3 columns]

# %%
from datetime import date

import datetime



# # Considering data from 2000 to 2022
# start = datetime.datetime(2018, 1, 1)
# end = date.today().strftime("%Y-%m-%d")

stocks = Path('./../resources/stock_list.txt').read_text().split("\n")
index=1
for s in stocks:
    print(s)
    df = yf.download( s, start , end)
    close = df['Close']

    close_df = close.reset_index().rename(columns={'Date':'ds', 'Close':'y'})
    close_df['y'] = np.log(close_df['y'])
    model = Prophet(daily_seasonality=True)
    model.fit(close_df)
    pkl_path = "./../resources/fbprophet/model/"+s+".model"
    with open(pkl_path, "wb") as f:
        pickle.dump(model, f)

    #     # save the dataframe
    #     forecast.to_pickle("./../../resources/fbprophet/forecast/"+s+".forecast")
    print(index,"*** Data Saved for -> ",s)
    index = index+1
# Out:
# AARTIIND.NS
# [*********************100%***********************]  1 of 1 completed
# Initial log joint probability = -2.21695
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#       99       4354.35    0.00187269       2567.83           1           1      134
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      199       4393.03    0.00782259        1084.5           1           1      246
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      299       4412.35    0.00316995        3093.4           1           1      354
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      399       4429.81    0.00035812       1416.48      0.7801      0.7801      467
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      499        4434.2   0.000213285       3829.91      0.1658      0.1658      583
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      599       4438.33   0.000258659       1970.75      0.5854     0.05854      707
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      699       4447.09    0.00155697       2024.66           1           1      827
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      799       4450.85    0.00179421       1236.06           1           1      942
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      899       4453.17   0.000367827       793.591      0.8335      0.8335     1063
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      999       4455.86   0.000106473       404.105           1           1     1173
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#     1099       4458.24    0.00212695       2346.38           1           1     1285
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#     1199        4459.5    0.00115423        1070.3      0.3213           1     1404
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#     1299       4460.65    0.00263736       768.877           1           1     1521
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#     1399       4461.71   8.64139e-05       407.812      0.6317      0.6317     1634
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#     1499       4462.42   0.000330782       495.792           1           1     1750
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#     1599        4463.1   0.000133409       192.875           1           1     1876
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#     1699       4463.31    0.00077298       374.094           1           1     2004
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#     1708       4463.36   6.19484e-06       374.219   2.104e-08       0.001     2064  LS failed, Hessian reset
#     1747       4463.49    1.2231e-05       279.474   7.602e-08       0.001     2166  LS failed, Hessian reset
#     1799       4463.52   1.30783e-05       71.4027      0.4004           1     2237
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#     1884        4463.7   2.12667e-06        146.36   1.386e-08       0.001     2390  LS failed, Hessian reset
#     1899       4463.72   2.04245e-05       50.8932           1           1     2407
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#     1999       4463.88   0.000963941       625.621      0.2806           1     2531
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#     2099       4464.98   9.72308e-05       435.712           1           1     2651
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#     2199       4465.32   3.10574e-05       137.361      0.9514      0.9514     2776
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#     2299       4465.44   0.000336108       117.361      0.2317           1     2904
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#     2363       4465.56   3.48718e-05       160.499   7.194e-08       0.001     3025  LS failed, Hessian reset
#     2399       4465.64   5.20994e-05       162.536           1           1     3065
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#     2410       4465.67   4.05298e-06       196.667   7.503e-09       0.001     3122  LS failed, Hessian reset
#     2499       4465.79   0.000351103       119.576       0.674       0.674     3233
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#     2599       4465.99   0.000131042       287.647           1           1     3355
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#     2697       4466.04   1.08756e-06       68.2345   8.432e-09       0.001     3532  LS failed, Hessian reset
#     2699       4466.04   7.11276e-05       168.553           1           1     3535
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#     2799        4466.2   0.000504363       309.987      0.4382      0.4382     3658
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#     2899       4467.65   0.000385267       496.886           1           1     3775
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#     2999       4468.53   0.000213961       216.077           1           1     3896
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#     3071       4468.77   7.58263e-06       484.285   1.887e-08       0.001     4041  LS failed, Hessian reset
#     3099       4468.89   1.07335e-05       542.356      0.2425      0.2425     4079
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#     3176          4469   1.84444e-06       125.533   1.951e-08       0.001     4216  LS failed, Hessian reset
#     3199          4469    3.9601e-06        94.816           1           1     4245
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#     3260       4469.04   6.73134e-06       141.851   7.505e-08       0.001     4390  LS failed, Hessian reset
#     3292       4469.04   1.28197e-06       95.7981   1.481e-08       0.001     4477  LS failed, Hessian reset
#     3299       4469.04   1.94375e-06       62.9402           1           1     4486
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#     3305       4469.04    2.0304e-07       65.1839      0.2246           1     4497
# Optimization terminated normally:
#   Convergence detected: relative gradient magnitude is below tolerance
# 1 *** Data Saved for ->  AARTIIND.NS
# ABBOTINDIA.NS
# [*********************100%***********************]  1 of 1 completed
# Initial log joint probability = -2.2991
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#       99       4721.26     0.0023192       3007.46      0.8636      0.8636      122
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      199       4841.75    0.00039485       1587.45       0.986       0.986      236
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      299       4922.72    0.00886351       14912.7           1           1      349
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      399       5028.31    0.00801478        4555.9      0.9595      0.9595      460
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      499       5067.42    0.00238283       10532.1           1           1      574
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      599       5094.74      0.027575       9779.93           1           1      690
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      699        5129.6    0.00995236       6722.47           1           1      814
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      799       5146.57     0.0013896       12710.4       0.692       0.692      926
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      899       5162.54   0.000141866       3528.34           1           1     1036
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      999       5173.39     0.0086219       6630.59           1           1     1147
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#     1099       5190.57    0.00137295       2068.42           1           1     1263
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#     1199       5199.65    0.00870241       4206.01       1.434      0.1434     1378
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#     1299       5205.35    0.00137442       2026.62           1           1     1492
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#     1399       5218.42     0.0288193       11126.5        1.14       0.114     1608
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#     1499       5237.16     0.0005751       3160.67           1           1     1715
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#     1599       5245.66     0.0015351       2588.91      0.3036           1     1832
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#     1699       5248.25   0.000214767       974.479           1           1     1940
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#     1799       5250.29   0.000394505       2593.01       2.003      0.2003     2049
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#     1899       5254.37   0.000160064       3860.88           1           1     2158
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#     1999       5255.74   0.000110213       1787.64      0.8722      0.8722     2268
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#     2099       5256.44    0.00349858       8042.02           1           1     2377
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#     2199       5259.22   0.000253712       2231.98           1           1     2487
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#     2299       5259.69   0.000415021       2744.32      0.3662           1     2598
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#     2399       5260.44   0.000190235       636.203      0.8509      0.8509     2711
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#     2499       5260.81   1.69712e-05       127.181           1           1     2824
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#     2599       5261.09   0.000184333       486.118           1           1     2936
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#     2699       5261.52   1.94763e-05       305.516           1           1     3053
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#     2799       5262.85   0.000926247       1215.09      0.9989      0.9989     3167
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#     2899       5263.27   4.20381e-05       715.235     0.09024           1     3278
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#     2999        5263.8   0.000119647       685.268           1           1     3390
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#     3099       5264.16     1.447e-05           120      0.6175      0.6175     3509
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#     3199       5264.22   2.81071e-05       281.709      0.3646      0.7063     3623
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#     3299       5264.42    2.3303e-05       394.495      0.4711      0.4711     3735
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#     3399        5264.8    0.00112187       1118.01           1           1     3850
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#     3499       5265.44    0.00213345       565.133           1           1     3968
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#     3599       5266.07   0.000200226       1505.33           1           1     4082
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#     3699       5266.38   0.000333314       627.251           1           1     4194
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#     3799       5266.59   6.37042e-06       153.868           1           1     4307
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#     3899       5266.67   8.33546e-05       220.782           1           1     4420
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#     3999       5266.73   6.83871e-05       476.347           1           1     4534
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#     4099       5267.05   5.54241e-05       134.463           1           1     4659
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#     4199       5267.46   0.000130261       458.255           1           1     4777
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#     4299       5267.72   9.99767e-05       210.749           1           1     4894
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#     4357       5268.54   1.42465e-05       964.908    1.51e-08       0.001     5003  LS failed, Hessian reset
#     4399       5268.73   1.02562e-05       215.475           1           1     5056
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#     4499       5268.91   1.49553e-05        173.58           1           1     5172
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#     4599       5269.03   0.000191728       1887.63     0.03544      0.6035     5288
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#     4699       5269.17   7.04413e-06       286.129           1           1     5408
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#     4799        5269.3   9.31335e-05       279.992           1           1     5525
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#     4899       5269.36    3.4662e-05       157.143           1           1     5643
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#     4943       5269.36   5.94564e-07       38.8249   1.176e-08       0.001     5734  LS failed, Hessian reset
# Optimization terminated normally:
#   Convergence detected: relative gradient magnitude is below tolerance
# 2 *** Data Saved for ->  ABBOTINDIA.NS
# ACC.NS
# [*********************100%***********************]  1 of 1 completed
# Initial log joint probability = -2.56948
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#       99       4440.09    0.00241451       1853.62           1           1      118
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      199       4510.06   0.000628106       3085.18           1           1      226
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      299       4572.25    0.00672733       2143.22           1           1      335
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      399       4613.64    0.00102629        2881.4     0.09893           1      448
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      499       4638.01   0.000714523       1218.49      0.5231      0.5231      565
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      599       4661.34   0.000349957       1516.46           1           1      677
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      699       4707.92    0.00480444       4016.11           1           1      795
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      799       4736.21    0.00415727       1669.62           1           1      909
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      899       4744.85    0.00271319       2926.44           1           1     1019
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      999       4762.17   0.000613237       465.283           1           1     1139
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#     1099       4771.21   0.000141079       1125.38           1           1     1259
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#     1199       4776.45    0.00146647       471.006           1           1     1379
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#     1299       4785.57    0.00627273       932.816           1           1     1488
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#     1399       4797.33   0.000165433       1523.77      0.2212           1     1603
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#     1499       4806.45   0.000160049       3984.41      0.4158           1     1713
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#     1599        4808.9    0.00027088       1143.42           1           1     1823
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#     1699       4813.19   0.000246184       478.753           1           1     1939
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#     1799       4814.65   0.000775412       600.985           1           1     2046
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#     1899       4825.35     0.0009173       3402.16      0.9361      0.9361     2159
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#     1999       4827.12   5.95145e-05        364.79       0.956       0.956     2270
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#     2099        4829.2   0.000813843       656.401           1           1     2385
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#     2199       4830.76   0.000578434       1001.74           1           1     2496
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#     2299       4831.51   2.67047e-05       1528.65      0.1739      0.1739     2615
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#     2399       4834.13   0.000665764       711.198           1           1     2728
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#     2499       4839.91   0.000217626        1539.6           1           1     2834
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#     2599       4845.85   0.000253742       680.775           1           1     2941
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#     2699       4848.68    0.00136899       2469.33           1           1     3051
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#     2799       4851.25   0.000430625       851.325       0.693       0.693     3167
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#     2844       4853.51   5.75318e-06       972.185   7.203e-09       0.001     3262  LS failed, Hessian reset
#     2899       4854.42   0.000175202       631.478      0.7964      0.7964     3323
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#     2999       4855.62   4.28973e-05       857.198      0.9063      0.9063     3436
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#     3099       4856.53   3.05388e-05       415.795           1           1     3548
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#     3199       4857.56   0.000658498       458.907           1           1     3658
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#     3299       4858.14    9.0029e-05       187.464           1           1     3775
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#     3399        4858.9    0.00062726       1371.71           1           1     3885
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#     3499       4860.45    0.00050461       327.635           1           1     4000
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#     3599       4862.16   0.000127847       452.263           1           1     4113
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#     3699       4862.92   6.21794e-05       154.496           1           1     4226
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#     3752       4863.13   3.72467e-06       627.051   7.531e-09       0.001     4336  LS failed, Hessian reset
#     3799       4863.25   6.07978e-05       474.895           1           1     4390
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#     3899       4863.49   0.000559811       2096.56           1           1     4508
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#     3999       4864.29   0.000118113       254.329           1           1     4622
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#     4086       4864.45   7.49178e-06       515.542    5.85e-08       0.001     4771  LS failed, Hessian reset
#     4099       4864.47   4.53308e-06       374.087      0.2397      0.2397     4785
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#     4199       4864.77    0.00119772       1978.11           1           1     4905
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#     4299       4865.94     0.0239772       796.128           1           1     5021
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#     4341       4866.26   7.99126e-06       1495.54   4.894e-09       0.001     5116  LS failed, Hessian reset
#     4399       4866.86   0.000961836       633.572           1           1     5177
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#     4499       4868.03    0.00021092       1977.99      0.2881           1     5289
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#     4599       4868.36   0.000171452       346.783           1           1     5410
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#     4643       4868.53   1.51802e-06       284.347   7.952e-09       0.001     5514  LS failed, Hessian reset
#     4699       4868.63   2.51503e-05       131.963           1           1     5576
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#     4799       4868.82   2.27194e-05       205.009      0.8541      0.8541     5692
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#     4899       4868.86   2.68343e-05       84.2981           1           1     5811
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#     4999       4869.13   0.000191577       1435.46       0.377           1     5935
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#     5012        4869.2   5.84723e-07       120.574   4.171e-09       0.001     5996  LS failed, Hessian reset
#     5099       4869.27   0.000750338       551.026           1           1     6105
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#     5118        4869.3   3.91139e-06       425.551   1.354e-08       0.001     6174  LS failed, Hessian reset
#     5178       4869.35    4.5258e-07       79.1829   9.486e-09       0.001     6288  LS failed, Hessian reset
#     5199       4869.36   1.94213e-05       281.748           1           1     6315
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#     5285       4869.58   8.64375e-06       1558.89     6.8e-09       0.001     6459  LS failed, Hessian reset
#     5299       4869.65   0.000115158       1114.71           1           1     6474
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#     5399       4869.87   1.17428e-05        286.36           1           1     6588
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#     5499       4869.92   4.28962e-05       364.977      0.6812      0.6812     6719
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#     5556       4869.96   2.79477e-06       234.025   2.472e-08       0.001     6836  LS failed, Hessian reset
#     5599       4869.97    0.00010177       165.856           1           1     6889
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#     5699          4870   8.32233e-05       118.059      0.8198      0.8198     7009
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#     5799       4870.06   7.17213e-05        151.23           1           1     7130
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#     5899        4870.1   9.84666e-05       125.906           1           1     7248
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#     5999        4870.5   0.000230094       129.877           1           1     7364
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#     6099       4870.84   0.000444463       285.179           1           1     7487
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#     6199        4871.2   2.15598e-05       459.206      0.7311      0.7311     7601
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#     6256       4871.54   7.06466e-07       134.732   3.285e-09       0.001     7718  LS failed, Hessian reset
#     6299        4871.6    0.00019143       1014.84      0.3812           1     7767
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#     6399       4871.66    8.7263e-05       480.625      0.3237           1     7888
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#     6444       4871.69   1.32488e-06       208.893    2.82e-09       0.001     7995  LS failed, Hessian reset
#     6499       4871.75   5.98912e-06       135.323           1           1     8061
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#     6527       4871.76   6.86725e-07       135.572    3.56e-09       0.001     8139  LS failed, Hessian reset
#     6575       4871.77   3.99501e-07       76.3212   3.221e-09       0.001     8248  LS failed, Hessian reset
#     6599       4871.78   3.00437e-06       67.2273      0.8708      0.8708     8277
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#     6632       4871.81   7.03533e-07       142.897   4.338e-09       0.001     8359  LS failed, Hessian reset
#     6683       4871.81   8.87543e-07       126.968   1.482e-08       0.001     8468  LS failed, Hessian reset
#     6699       4871.81   1.35386e-06       98.4367      0.3159      0.3159     8487
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#     6762       4871.87   2.18858e-06       391.082   9.734e-09       0.001     8603  LS failed, Hessian reset
#     6799       4871.92   4.63477e-05       200.484       0.149      0.6813     8647
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#     6815       4871.92   1.61021e-06       309.517   3.924e-09       0.001     8714  LS failed, Hessian reset
#     6837       4871.93   4.43052e-07        91.266   3.904e-09       0.001     8789  LS failed, Hessian reset
#     6872       4871.94   1.06804e-06       194.506   6.961e-09       0.001     8881  LS failed, Hessian reset
#     6878       4871.94   3.31417e-07       36.5449      0.2764           1     8890
# Optimization terminated normally:
#   Convergence detected: relative gradient magnitude is below tolerance
# 3 *** Data Saved for ->  ACC.NS
# ADANIENT.NS
# [*********************100%***********************]  1 of 1 completed
# Initial log joint probability = -5.01005
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#       99       3440.47      0.061516       4736.07           1           1      121
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      199       3640.51    0.00531893       6903.82      0.3071      0.6886      236
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      299       3734.68    0.00510456       2110.67           1           1      353
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      399        3790.2    0.00428661       1472.28           1           1      470
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      499       3848.61    0.00195599       850.532           1           1      582
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      599       3883.01    0.00210702       385.787           1           1      694
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      699       3899.14    0.00157786       646.023           1           1      808
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      799       3907.56    0.00120555       632.111           1           1      916
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      899       3915.47     0.0164009       1517.03           1           1     1025
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      999       3923.78    0.00413438       1036.02           1           1     1143
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#     1099       3927.66   0.000392071       993.631      0.8394      0.8394     1258
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#     1199       3929.69    0.00126334       221.282      0.4303      0.9542     1369
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#     1299       3932.26     0.0006283       253.256           1           1     1483
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#     1399       3935.26   0.000808795         807.9      0.2582      0.2582     1597
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#     1484       3937.44    1.9441e-05       366.691   1.865e-07       0.001     1746  LS failed, Hessian reset
#     1499       3937.82   0.000113507       146.473           1           1     1767
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#     1599        3939.1   0.000873044        356.54      0.6583      0.6583     1888
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#     1699       3940.39   0.000218788       205.381       1.889      0.1889     2008
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#     1799       3944.68    0.00146372       204.407           1           1     2121
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#     1896       3945.74   6.78249e-06       232.006   1.684e-08       0.001     2281  LS failed, Hessian reset
#     1899       3945.75   1.90123e-05       127.452           1           1     2284
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#     1999       3946.49    0.00018815       169.061           1           1     2400
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#     2099       3947.15   0.000793602        98.214           1           1     2509
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#     2199       3948.33     0.0071722       474.858      0.7072      0.7072     2627
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#     2299        3953.5   0.000129014       127.384           1           1     2744
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#     2399       3954.58   0.000331979       273.213      0.7683      0.7683     2857
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#     2499       3955.53   3.49575e-05       200.459      0.5937      0.9316     2989
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#     2599       3955.89   0.000143579       112.038     0.09134           1     3107
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#     2699        3956.7     0.0024841         133.3           1           1     3219
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#     2799       3967.35    0.00645787       922.915           1           1     3331
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#     2861       3968.39    1.6939e-05       560.516   4.653e-08       0.001     3450  LS failed, Hessian reset
#     2899       3968.84   0.000312601       172.018      0.5249      0.5249     3496
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#     2999       3969.73    0.00015652        246.63      0.5831      0.5831     3616
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#     3099       3970.36   0.000404827       110.775           1           1     3736
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#     3199       3970.79   0.000133254       60.5685           1           1     3851
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#     3299       3971.05   1.24487e-05       42.7839      0.1678           1     3969
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#     3399       3971.32   0.000207902       377.067      0.6436      0.6436     4086
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#     3499       3971.57   5.32856e-05       103.413           1           1     4199
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#     3599       3971.96    0.00638637       469.308           1           1     4317
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#     3699       3972.34   0.000336039       131.035           1           1     4432
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#     3799       3972.77   0.000210474       226.062           1           1     4545
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#     3830       3972.81   1.52359e-06       70.1473   1.969e-08       0.001     4643  LS failed, Hessian reset
#     3899       3972.91   3.08094e-05       63.3553      0.4424      0.4424     4730
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#     3918       3972.93   1.24462e-06       64.4233   1.619e-08       0.001     4801  LS failed, Hessian reset
#     3997       3972.97   7.37249e-08       45.7626      0.1348      0.1348     4902
# Optimization terminated normally:
#   Convergence detected: relative gradient magnitude is below tolerance
# 4 *** Data Saved for ->  ADANIENT.NS
# ADANIPORTS.NS
# [*********************100%***********************]  1 of 1 completed
# Initial log joint probability = -3.10276
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#       99       4115.61    0.00345274       12361.2      0.5074      0.5074      124
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      199       4196.33     0.0111234       2447.64      0.2534           1      237
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      299       4245.93    0.00243325       1019.78           1           1      350
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      399       4271.43   0.000568767       931.472      0.5596      0.5596      463
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      499       4307.64    0.00250011       991.675           1           1      577
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      599       4321.96   0.000324349       490.762           1           1      693
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      699       4342.49   0.000823793        3288.7           1           1      811
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      799       4356.82      0.021295       1797.58      0.3815           1      927
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      899       4364.72    0.00389251       2383.91           1           1     1036
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      999       4371.96     0.0046979       950.367           1           1     1147
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#     1099       4379.92   0.000557301         560.5           1           1     1269
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#     1199       4385.38   0.000382333       2171.23     0.04857           1     1389
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#     1299        4390.1   0.000201997       438.372           1           1     1509
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#     1399       4394.34   0.000310974       231.883      0.4615           1     1624
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#     1499       4395.49   0.000209595       511.707           1           1     1739
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#     1599       4397.33    0.00119262       3044.07      0.2657      0.9499     1851
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#     1699       4404.55    0.00109148       1042.76           1           1     1961
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#     1799       4424.43    0.00109633       728.523      0.8116      0.8116     2078
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#     1899       4429.84   0.000195314       733.894           1           1     2189
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#     1999       4432.58   8.37922e-05        193.69           1           1     2305
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#     2099        4435.3   0.000270733       329.898           1           1     2417
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#     2199          4436   0.000158981       815.208      0.3689      0.3689     2537
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#     2299       4437.57    0.00162052       353.082      0.4688           1     2650
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#     2399       4439.48   0.000136981       227.135          10           1     2778
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#     2499       4439.99   0.000353616       439.277      0.3054           1     2893
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#     2524       4440.18   6.18971e-06       408.209   3.191e-08       0.001     2970  LS failed, Hessian reset
#     2599       4440.64   1.73436e-05       471.019     0.03993           1     3059
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#     2699       4442.02    0.00329849       670.554           1           1     3189
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#     2799       4446.66    0.00261878       269.958      0.8629      0.8629     3298
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#     2899       4449.95   0.000505619        284.46           1           1     3413
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#     2999       4451.41    0.00122456       820.721           1           1     3527
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#     3099       4453.12   0.000409183       1090.43           1           1     3645
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#     3199        4453.9   0.000111864       715.598       1.015      0.1015     3760
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#     3299       4455.39    0.00122622       354.459           1           1     3877
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#     3399       4456.06   1.58938e-05       388.774      0.3567      0.3567     3994
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#     3481       4456.77   2.39727e-06        218.18   7.792e-09       0.001     4144  LS failed, Hessian reset
#     3499       4456.88   8.87381e-05       175.475           1           1     4165
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#     3599       4457.45   0.000174976       329.754      0.2877           1     4283
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#     3699       4458.31   6.12207e-05       104.019           1           1     4404
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#     3799       4458.57   3.54903e-05       118.048           1           1     4520
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#     3899       4458.75   6.47307e-05       78.1054           1           1     4642
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#     3999        4459.1   0.000120142       153.363           1           1     4758
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#     4005       4459.11   4.16571e-06       371.092   1.465e-08       0.001     4807  LS failed, Hessian reset
#     4099       4459.25   1.15643e-05       80.2726           1           1     4922
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#     4190       4459.32   8.08173e-07       74.5906   8.027e-09       0.001     5080  LS failed, Hessian reset
#     4199       4459.32   1.68624e-05       53.8228           1           1     5091
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#     4238       4459.34   1.36737e-06       126.246   9.689e-09       0.001     5184  LS failed, Hessian reset
#     4299       4459.42   0.000265175       507.105      0.2376      0.2376     5261
# ...
#     2599       4609.14   0.000682068       377.563       4.315      0.4315     2944
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#     2699       4610.12    7.6831e-05       219.027           1           1     3053
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#     2799       4610.61   0.000373569       537.388           1           1     3171
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#     2878       4610.97   2.79266e-06       319.556   9.168e-09       0.001     3318  LS failed, Hessian reset
#     2899          4611   7.02133e-05       330.385           1           1     3340
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#     2999       4611.79    0.00183712       244.147           1           1     3451
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#     3099       4612.55   4.65155e-05       282.523           1           1     3564
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#     3199       4612.89   4.66816e-05       400.909      0.1104     0.06333     3680
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#     3299       4613.24    0.00116681       720.726      0.4104      0.4104     3796
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#     3399        4613.8   0.000268563        519.33           1           1     3907
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#     3499       4614.44   0.000721756       347.368       2.846      0.2846     4025
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#     3599       4615.26   0.000634384       647.498      0.8615      0.8615     4137
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#     3699       4617.85   0.000535578       701.501       0.483       0.483     4247
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#     3799       4618.88   0.000145161       436.919           1           1     4361
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#     3899        4619.1   0.000158594       110.768           1           1     4480
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#     3999       4619.48   6.09026e-06       164.729      0.6349      0.6349     4594
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#     4099       4619.65     1.342e-05       117.605           1           1     4707
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#     4199       4620.11    0.00025836       612.377      0.2649      0.2649     4818
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#     4299       4620.73   8.19411e-05       161.731           1           1     4934
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#     4399       4620.99   0.000111354        136.46           1           1     5047
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#     4494       4621.22   1.27364e-06       168.659   6.155e-09       0.001     5198  LS failed, Hessian reset
#     4499       4621.24   0.000147454       312.256           1           1     5204
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#     4599       4621.31   2.31653e-05       46.5109           1           1     5317
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#     4640       4621.35       6.2e-06       526.507   1.887e-08       0.001     5426  LS failed, Hessian reset
#     4699       4621.41   9.94512e-06       36.7779           1           1     5500
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#     4703       4621.41   2.73249e-06       40.5195           1           1     5505
# Optimization terminated normally:
#   Convergence detected: relative gradient magnitude is below tolerance
# 176 *** Data Saved for ->  VOLTAS.NS
# WIPRO.NS
# [*********************100%***********************]  1 of 1 completed
# Initial log joint probability = -3.02485
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#       99       4115.66    0.00199108        2580.9           1           1      114
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      199       4309.22     0.0541583       11815.1           1           1      237
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      299       4425.99    0.00289754        5525.9           1           1      355
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      399       4499.75    0.00464005       4577.67           1           1      473
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      499       4520.17    0.00329706       2776.37      0.4978           1      589
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      599       4537.51   0.000326486       1990.38           1           1      701
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      699       4552.79     0.0019288       2073.73           1           1      815
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      799       4604.31   0.000639609       2480.34      0.3798           1      936
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      899       4611.85    0.00336594       709.035      0.1787           1     1052
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      999       4618.12   0.000356471       1166.27      0.4556      0.4556     1163
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#     1099        4622.5   0.000669787       1195.63           1           1     1281
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#     1199       4625.39    0.00441036       2617.43           1           1     1393
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#     1299       4626.61   0.000199612       134.122           1           1     1503
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#     1399       4627.44   0.000430945       450.091      0.3699           1     1621
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#     1499       4628.89   9.13256e-05       813.858      0.3436           1     1737
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#     1599       4632.13    0.00144189       1742.19           1           1     1847
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#     1699       4634.23   7.96726e-05       648.147      0.1994           1     1968
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#     1799       4636.03    0.00384897       3256.76      0.5049      0.5049     2083
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#     1899       4637.67   0.000395157       488.383           1           1     2196
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#     1999       4644.34   0.000136155       442.308           1           1     2307
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#     2099       4646.72    0.00226991       2251.34           1           1     2422
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#     2199       4648.16   0.000741628        1429.3      0.5153      0.5153     2532
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#     2299       4649.76   0.000713062       1163.27           1           1     2643
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#     2399       4650.31   0.000444631       770.029      0.3622           1     2760
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#     2499       4650.81    0.00130882        1119.4           1           1     2886
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#     2599       4651.13   2.39872e-05       81.7247           1           1     3010
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#     2655        4651.2   1.30524e-06       156.288   6.138e-09       0.001     3133  LS failed, Hessian reset
#     2699       4651.25   5.66743e-05       84.6687           1           1     3187
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#     2799       4651.92   0.000218493       393.274           1           1     3303
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#     2869       4653.37   3.67221e-06       364.938   4.706e-09       0.001     3431  LS failed, Hessian reset
#     2899       4653.58   0.000279166        1347.9           1           1     3465
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#     2999       4654.01   3.47577e-05       188.562           1           1     3577
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#     3099        4654.2   4.37115e-05       167.529       2.042      0.2042     3691
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#     3107       4654.21   1.09693e-06       113.954   4.675e-09       0.001     3753  LS failed, Hessian reset
#     3132       4654.23   1.18661e-06       148.875   7.791e-09       0.001     3832  LS failed, Hessian reset
#     3199       4654.37    7.9811e-06       110.591      0.2344      0.8248     3912
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#     3299       4654.59    5.7793e-06       107.238      0.1776      0.1776     4031
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#     3350       4654.61   9.52591e-07       112.127    1.21e-08       0.001     4143  LS failed, Hessian reset
#     3385       4654.62   2.45813e-08       57.4862    0.007883      0.1454     4190
# Optimization terminated normally:
#   Convergence detected: relative gradient magnitude is below tolerance
# 177 *** Data Saved for ->  WIPRO.NS
# ZEEL.NS
# [*********************100%***********************]  1 of 1 completed
# Initial log joint probability = -3.94134
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#       99       3592.46    0.00186143       973.011     0.06486           1      124
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      199        3657.2    0.00587104       409.324           1           1      235
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      299       3675.91     0.0155957       424.412           1           1      351
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      399       3686.87    0.00792431       363.057      0.8171      0.8171      463
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      499       3690.92    0.00675282       1318.01           1           1      583
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      599       3694.99   0.000138208       264.452           1           1      696
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      648       3696.02   1.58285e-05       242.801   7.348e-08       0.001      799  LS failed, Hessian reset
#      699       3696.66   0.000742847       83.2887       3.521      0.3521      859
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      794       3698.17   4.19861e-06       69.5948    5.24e-08       0.001     1020  LS failed, Hessian reset
#      799       3698.23   0.000719781       233.404           1           1     1027
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      880       3699.64   3.03088e-05       283.754   3.141e-08       0.001     1172  LS failed, Hessian reset
#      899       3700.31   0.000125446       203.768      0.9089      0.9089     1194
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      999       3701.19   0.000168974        129.28           1           1     1319
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#     1099       3701.97    0.00533991       254.164           1           1     1455
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#     1117       3702.69   1.11967e-05         156.3   1.125e-07       0.001     1530  LS failed, Hessian reset
#     1170       3702.94    1.3623e-05       200.629   8.765e-08       0.001     1648  LS failed, Hessian reset
#     1199       3702.98   3.53342e-05       106.259           1           1     1680
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#     1299       3704.85    0.00483595       773.903           1           1     1796
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#     1399       3706.38   0.000307598       140.975           1           1     1903
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#     1499       3706.82   5.18103e-05       88.1595           1           1     2027
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#     1599       3707.21    0.00103571       787.282      0.7331      0.7331     2141
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#     1668        3707.4   6.82199e-06       126.542   5.839e-08       0.001     2265  LS failed, Hessian reset
#     1699       3707.43    5.5123e-05       232.773           1           1     2300
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#     1773       3707.46   2.82495e-05       221.716   4.276e-07       0.001     2429  LS failed, Hessian reset
#     1799       3707.47   3.12614e-05       80.4401       0.331           1     2464
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#     1814       3707.47   6.61826e-07       58.3495   1.418e-08       0.001     2524  LS failed, Hessian reset
#     1815       3707.47   3.35094e-07       48.2309           1           1     2525
# Optimization terminated normally:
#   Convergence detected: relative gradient magnitude is below tolerance
# 178 *** Data Saved for ->  ZEEL.NS
